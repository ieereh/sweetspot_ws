# %%
import pandas as pd

# %%
filename = 'data/NewTenant.xlsx'

# %%
df1 = pd.read_excel(filename, engine='openpyxl')

# %%
df1
# Out:
#    Unnamed: 0                  Unnamed: 1  \
# 0         NaN  테넌트 라이브러리 New Tenant 발굴 로직
# 1         NaN                         NaN
# 2         NaN                         NaN
# 3         NaN                         가중치
# 4         NaN                         NaN
# 5         NaN                          산식
# 6         NaN                         NaN
# 7         NaN                         NaN
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                     네이버맵 방문자리뷰수 점수
# 3                                                0.2
# 4                                                 20
# 5                                        500 이하 : 0점
# 6                                      1200 이상 : 20점
# 7  IF(셀값>=500,IF(셀값<=1200,((셀값-300)*(ROUND(100/(1...
#
#                                           Unnamed: 3  \
# ...

# %%
df2 = pd.read_csv('data/일반음식점2.csv')
# Out:
# C:\Users\akdhk\AppData\Local\Temp\ipykernel_9188\3162037680.py:1: DtypeWarning: Columns (2,8,13,14,25,27,28,29,30,36,39,41,42,46,48,56,57,59,60,61,62,63,66,71,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/일반음식점2.csv')

# %%
df2 = df2.drop(df2.columns[25:82], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497600 entries, 0 to 497599
# Data columns (total 25 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   개방자치단체코드  497600 non-null  int64
#  1   관리번호      497600 non-null  object
#  2   인허가일자     497600 non-null  object
#  3   인허가취소일자   0 non-null       float64
#  4   영업상태코드    497600 non-null  int64
#  5   영업상태명     497600 non-null  object
#  6   상세영업상태코드  497600 non-null  int64
#  7   상세영업상태명   497600 non-null  object
#  8   폐업일자      372069 non-null  object
#  9   휴업시작일자    0 non-null       float64
#  10  휴업종료일자    0 non-null       float64
#  11  재개업일자     0 non-null       float64
#  12  전화번호      329662 non-null  object
#  13  소재지면적     464062 non-null  object
#  14  소재지우편번호   497366 non-null  object
#  15  지번주소      497373 non-null  object
#  16  도로명주소     247909 non-null  object
#  17  도로명우편번호   243991 non-null  float64
#  18  사업장명      497599 non-null  object
# ...

# %%
df2.shape
# Out:
# (497600, 25)

# %%
df2.head()
# Out:
#    개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3010000  3010000-101-2023-00540  2023-11-03      NaN       1  영업/정상
# 1   3220000  3220000-101-2023-00459  2023-03-31      NaN       1  영업/정상
# 2   3230000  3230000-101-2023-00343  2023-05-12      NaN       1  영업/정상
# 3   3230000  3230000-101-2023-00220  2023-03-31      NaN       1  영업/정상
# 4   3230000  3230000-101-2023-00222  2023-03-31      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  ...                      지번주소  \
# 0         1      영업  NaN     NaN  ...     서울특별시 중구 을지로6가 18-137
# 1         1      영업  NaN     NaN  ...  서울특별시 강남구 역삼동 711-6 역삼자이
# 2         1      영업  NaN     NaN  ...        서울특별시 송파구 가락동 84-6
# 3         1      영업  NaN     NaN  ...  서울특별시 송파구 방이동 57 One57빌당
# 4         1      영업  NaN     NaN  ...  서울특별시 송파구 가락동 46-11 문종빌딩
#
#                                             도로명주소 도로명우편번호         사업장명  \
# 0                서울특별시 중구 장충단로 249-10, 2층 (을지로6가)  4564.0     매취랑 동대문점
# ...

# %%
df2.describe()
# Out:
#            개방자치단체코드  인허가취소일자         영업상태코드       상세영업상태코드  휴업시작일자  휴업종료일자  \
# count  4.976000e+05      0.0  497600.000000  497600.000000     0.0     0.0
# mean   3.132479e+06      NaN       2.495454       1.747727     NaN     NaN
# std    7.502570e+04      NaN       0.868635       0.434317     NaN     NaN
# min    3.000000e+06      NaN       1.000000       1.000000     NaN     NaN
# 25%    3.070000e+06      NaN       1.000000       1.000000     NaN     NaN
# 50%    3.140000e+06      NaN       3.000000       2.000000     NaN     NaN
# 75%    3.200000e+06      NaN       3.000000       2.000000     NaN     NaN
# max    3.240000e+06      NaN       3.000000       2.000000     NaN     NaN
#
#        재개업일자        도로명우편번호        좌표정보(X)        좌표정보(Y)
# count    0.0  243991.000000  472319.000000  472319.000000
# mean     NaN    5191.200667  199331.433914  449190.906853
# std      NaN    2132.013167    7342.236933    5474.421004
# min      NaN    1000.000000  177915.685000    3160.060492
# ...

# %%
df2.dtypes
# Out:
# 개방자치단체코드      int64
# 관리번호         object
# 인허가일자        object
# 인허가취소일자     float64
# 영업상태코드        int64
# 영업상태명        object
# 상세영업상태코드      int64
# 상세영업상태명      object
# 폐업일자         object
# 휴업시작일자      float64
# 휴업종료일자      float64
# 재개업일자       float64
# 전화번호         object
# 소재지면적        object
# 소재지우편번호      object
# 지번주소         object
# 도로명주소        object
# 도로명우편번호     float64
# 사업장명         object
# 최종수정일자       object
# 데이터갱신구분      object
# 데이터갱신일자      object
# 업태구분명        object
# 좌표정보(X)     float64
# 좌표정보(Y)     float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)'],
#       dtype='object')

# %%
df3 = pd.read_csv('data/tenant.csv', encoding='cp949')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8206 entries, 0 to 8205
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   seq                       8206 non-null   int64
#  1   st_company_seq            8199 non-null   float64
#  2   nv_restaurant             8206 non-null   object
#  3   nv_restaurant_tel         8027 non-null   object
#  4   nv_address                8206 non-null   object
#  5   nv_address_lat            8206 non-null   float64
#  6   nv_address_long           8206 non-null   float64
#  7   nv_address_si             8164 non-null   object
#  8   nv_address_gu             8164 non-null   object
#  9   nv_address_dong           8163 non-null   object
#  10  nv_place_intro            3630 non-null   object
#  11  nv_sector                 8200 non-null   object
#  12  nv_insta_url              5329 non-null   object
# ...

# %%
df3.shape
# Out:
# (8206, 44)

# %%
df3.head()
# Out:
#    seq  st_company_seq nv_restaurant nv_restaurant_tel  \
# 0    1             2.0           도식화    0507-1342-7937
# 1    2          4768.0    뽕나무쟁이 선릉본점       02-558-9279
# 2    3           639.0        스케줄 성수    0507-1349-7458
# 3    4           220.0      사위식당 마곡점    0507-1495-2242
# 4    5          4769.0  레스토랑 파츠 강남N점    0507-1336-0329
#
#                   nv_address  nv_address_lat  nv_address_long nv_address_si  \
# 0     서울 마포구 와우산로17길 19-9 1층        37.54979        126.92179            서울
# 1           서울 강남구 역삼로65길 31        37.50320        127.05200            서울
# 2         서울 성동구 아차산로 104 2층        37.54444        127.05546            서울
# 3    서울 강서구 공항대로 227 1층 112호        37.55960        126.83269            서울
# 4  서울 강남구 테헤란로 129 강남N타워 B2층        37.49993        127.03237            서울
#
#   nv_address_gu nv_address_dong  ...         license_date  \
# 0           마포구             서교동  ...  2022-05-02 00:00:00
# ...

# %%
df3.describe()
# Out:
#                seq  st_company_seq  nv_address_lat  nv_address_long  \
# count  8206.000000     8199.000000     8206.000000      8206.000000
# mean   4904.446137     3631.158068       37.173819       125.752822
# std    2861.726976     2361.079282        3.688893        12.478399
# min       1.000000        1.000000        0.000000         0.000000
# 25%    2052.250000      538.000000       37.508835       126.925152
# 50%    5249.500000     3996.000000       37.537160       126.996910
# 75%    7406.750000     5499.000000       37.563137       127.046345
# max    9458.000000     7382.000000       37.685610       127.177830
#
#         nv_place_id  nv_visitor_review_cnt  nv_blog_review_cnt  \
# count  8.206000e+03            8206.000000         8206.000000
# mean   1.089434e+09             897.734219          328.066171
# std    6.749789e+08            1611.043526          600.433366
# min    1.098546e+07               0.000000            0.000000
# ...

# %%
df3.columns
# Out:
# Index(['seq', 'st_company_seq', 'nv_restaurant', 'nv_restaurant_tel',
#        'nv_address', 'nv_address_lat', 'nv_address_long', 'nv_address_si',
#        'nv_address_gu', 'nv_address_dong', 'nv_place_intro', 'nv_sector',
#        'nv_insta_url', 'nv_place_id', 'nv_visitor_review_cnt',
#        'nv_blog_review_cnt', 'nv_search_volume_monthly', 'seoul_data_area',
#        'insta_follower_cnt', 'gg_rating', 'gg_review_cnt', 'kk_rating',
#        'kk_rating_cnt', 'kk_review_cnt', 'nv_visitor_review_score',
#        'nv_blog_review_score', 'nv_search_volume_score', 'kk_rating_score',
#        'gg_rating_score', 'insta_follower_score', 'total_score',
#        'quarter_year', 'quarter_month', 'tenant_status', 'license_date',
#        'create_at', 'update_at', 'delete_at', 'brand_name', 'ld_place_cnt',
#        'kk_restaurant', 'kk_place_id', 'delete_reason', 'license_update_date'],
#       dtype='object')

# %%
df3['seoul_data_area'].isna().sum()
# Out:
# 0

# %%
df3[df3['seoul_data_area'] == 0]
# Out:
#        seq  st_company_seq nv_restaurant nv_restaurant_tel  \
# 100    101             1.0     앤티크커피 잠실점    0507-1355-7017
# 101    102             1.0  앤티크커피 영등포구청점     070-8845-3702
# 102    103             3.0   해피치즈스마일 연남점    0507-1336-6703
# 103    104             3.0   해피치즈스마일 노원점       02-933-0326
# 104    105             6.0   청춘닭꼬치 논현직영점    0507-1356-3236
# ...    ...             ...           ...               ...
# 5932  7185          5659.0          카페다오    0507-1359-5574
# 5943  7196          5354.0          심야식당    0507-1405-9570
# 5973  7226          5695.0          양가곱창       02-722-9295
# 5987  7240          5709.0          구마스시       02-735-2500
# 6270  7523          5947.0            드엠    0507-1319-3279
#
#                               nv_address  nv_address_lat  nv_address_long  \
# 100   서울 송파구 백제고분로41길 21-16 1층 앤티크커피 잠실점        37.50760        127.10633
# 101    서울 영등포구 국회대로29길 6 1층 앤티크커피 영등포구청점        37.52868        126.89679
# ...

# %%
len(df3.loc[df3['seoul_data_area'] == 0])
# Out:
# 5316

# %%
df3[df3['seoul_data_area'] == 0]
# Out:
#        seq  st_company_seq nv_restaurant nv_restaurant_tel  \
# 100    101             1.0     앤티크커피 잠실점    0507-1355-7017
# 101    102             1.0  앤티크커피 영등포구청점     070-8845-3702
# 102    103             3.0   해피치즈스마일 연남점    0507-1336-6703
# 103    104             3.0   해피치즈스마일 노원점       02-933-0326
# 104    105             6.0   청춘닭꼬치 논현직영점    0507-1356-3236
# ...    ...             ...           ...               ...
# 5932  7185          5659.0          카페다오    0507-1359-5574
# 5943  7196          5354.0          심야식당    0507-1405-9570
# 5973  7226          5695.0          양가곱창       02-722-9295
# 5987  7240          5709.0          구마스시       02-735-2500
# 6270  7523          5947.0            드엠    0507-1319-3279
#
#                               nv_address  nv_address_lat  nv_address_long  \
# 100   서울 송파구 백제고분로41길 21-16 1층 앤티크커피 잠실점        37.50760        127.10633
# 101    서울 영등포구 국회대로29길 6 1층 앤티크커피 영등포구청점        37.52868        126.89679
# ...

# %%
df3['quarter_month'].unique()
# Out:
# array([ 5,  0,  6,  7,  8,  9, 10], dtype=int64)

# %%
df4 = df3[['st_company_seq', 'nv_restaurant', 'nv_address', 'nv_address_gu', 'nv_address_dong', 'nv_sector', 
          'seoul_data_area', 'nv_visitor_review_cnt', 'nv_blog_review_cnt', 'nv_search_volume_monthly', 
          'insta_follower_cnt', 'gg_rating', 'gg_review_cnt', 'kk_rating', 'kk_rating_cnt', 'kk_review_cnt', 
          'total_score', 'brand_name', 'ld_place_cnt', 'kk_restaurant']]

# %%
df4
# Out:
#       st_company_seq nv_restaurant                 nv_address nv_address_gu  \
# 0                2.0           도식화     서울 마포구 와우산로17길 19-9 1층           마포구
# 1             4768.0    뽕나무쟁이 선릉본점           서울 강남구 역삼로65길 31           강남구
# 2              639.0        스케줄 성수         서울 성동구 아차산로 104 2층           성동구
# 3              220.0      사위식당 마곡점    서울 강서구 공항대로 227 1층 112호           강서구
# 4             4769.0  레스토랑 파츠 강남N점  서울 강남구 테헤란로 129 강남N타워 B2층           강남구
# ...              ...           ...                        ...           ...
# 8201          7378.0       양파이 한남점       서울 용산구 독서당로 65-11 1층           용산구
# 8202          7379.0     끝돈 건대입구역점    서울 광진구 아차산로 238 1층 103호           광진구
# 8203          7380.0       파티세리후르츠      서울 성동구 아차산로5길 37-1 1층           성동구
# 8204          7381.0          티플랜트           서울 서초구 동광로39길 46           서초구
# 8205          7382.0      록갈비 영등포점       서울 영등포구 영중로10길 44 1층          영등포구
#
# ...

# %%
df4['result'] = df4['nv_restaurant'] == df4['kk_restaurant']
# Out:
# C:\Users\akdhk\AppData\Local\Temp\ipykernel_9188\2785533575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['result'] = df4['nv_restaurant'] == df4['kk_restaurant']

# %%
len(df4['nv_restaurant'] == df4['kk_restaurant'])
# Out:
# 8206

# %%
len(df4.loc[df4['result'] == False])
# Out:
# 2930

# %%
df5 = pd.read_csv('data/tenant_sector.csv', encoding='cp949')

# %%
df5
# Out:
#        seq  tenant_seq  tenant_sector_info_seq         create_at update_at  \
# 0        1           1                    14.0  2023-08-29 10:59       NaN
# 1        2           2                     1.0  2023-08-29 10:59       NaN
# 2        3           3                     7.0  2023-08-29 10:59       NaN
# 3        4           4                     5.0  2023-08-29 10:59       NaN
# 4        5           5                     7.0  2023-08-29 10:59       NaN
# ...    ...         ...                     ...               ...       ...
# 6047  6302        7350                    17.0  2023-09-07 10:31       NaN
# 6048  6303        7351                    14.0  2023-09-07 10:31       NaN
# 6049  6304        7352                     7.0  2023-09-07 10:31       NaN
# 6050  6310        7303                    16.0  2023-09-07 10:48       NaN
# 6051  6311        7323                     6.0  2023-09-07 10:48       NaN
#
#       delete_at
# 0           NaN
# 1           NaN
# ...

# %%
df6 = pd.read_csv('data/tenant_sector_info.csv', encoding='utf-8')

# %%
df6
# Out:
#     seq             name         create_at  update_at  delete_at
# 0     1           족발, 보쌈  2023-08-28 16:51        NaN        NaN
# 1     2         찜, 탕, 찌개  2023-08-28 16:51        NaN        NaN
# 2     3  돈까스, 회, 일식, 해산물  2023-08-28 16:52        NaN        NaN
# 3     4               피자  2023-08-28 16:52        NaN        NaN
# 4     5           고기, 구이  2023-08-28 16:52        NaN        NaN
# 5     6               한식  2023-08-28 16:53        NaN        NaN
# 6     7               양식  2023-08-28 16:53        NaN        NaN
# 7     8               치킨  2023-08-28 16:53        NaN        NaN
# 8     9               중식  2023-08-28 16:53        NaN        NaN
# 9    10              아시안  2023-08-28 16:54        NaN        NaN
# 10   11        백반, 죽, 국수  2023-08-28 16:54        NaN        NaN
# 11   12              도시락  2023-08-28 16:54        NaN        NaN
# 12   13               분식  2023-08-28 16:54        NaN        NaN
# ...

# %%
df7 = pd.read_csv('data/일반음식점.csv', encoding='cp949')
# Out:
# C:\Users\akdhk\AppData\Local\Temp\ipykernel_8868\353849555.py:1: DtypeWarning: Columns (11,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df7 = pd.read_csv('data/일반음식점.csv', encoding='cp949')

# %%
df8 = pd.read_csv('data/휴게음식점.csv', encoding='cp949')
# Out:
# C:\Users\akdhk\AppData\Local\Temp\ipykernel_8868\719727721.py:1: DtypeWarning: Columns (11,39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv('data/휴게음식점.csv', encoding='cp949')

# %%
df7
# Out:
#               번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 0              1  일반음식점  07_24_04_P   3930000  5560000-101-2023-00271
# 1              2  일반음식점  07_24_04_P   4710000  4710000-101-2023-00096
# 2              3  일반음식점  07_24_04_P   3740000  3770000-101-2023-00341
# 3              4  일반음식점  07_24_04_P   3740000  3770000-101-2023-00339
# 4              5  일반음식점  07_24_04_P   4221000  4221000-101-2023-00058
# ...          ...    ...         ...       ...                     ...
# 2105701  2105702  일반음식점  07_24_04_P   3600000  3600000-101-1995-00101
# 2105702  2105703  일반음식점  07_24_04_P   3610000  3610000-101-2012-00009
# 2105703  2105704  일반음식점  07_24_04_P   3610000  3610000-101-2014-00098
# 2105704  2105705  일반음식점  07_24_04_P   3600000  3600000-101-2014-00060
# 2105705  2105706  일반음식점  07_24_04_P   3600000  3600000-101-2014-00059
#
#               인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직직원수 건물소유구분명  \
# ...

# %%
df7.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
#        '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
#        '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'],
#       dtype='object')

# %%
df8.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(x)', '좌표정보(y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총직원수',
#        '본사직원수', '공장사무직직원수', '공장판매직직원수', '공장생산직직원수', '건물소유구분명', '보증액', '월세액',
#        '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지', 'Unnamed: 47'],
#       dtype='object')

# %%
df7 = df7.drop(df7.columns[28:48], axis=1)

# %%
df8 = df8.drop(df8.columns[28:48], axis=1)

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105706 entries, 0 to 2105705
# Data columns (total 28 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   번호        int64
#  1   개방서비스명    object
#  2   개방서비스아이디  object
#  3   개방자치단체코드  int64
#  4   관리번호      object
#  5   인허가일자     object
#  6   인허가취소일자   float64
#  7   영업상태구분코드  int64
#  8   영업상태명     object
#  9   상세영업상태코드  int64
#  10  상세영업상태명   object
#  11  폐업일자      object
#  12  휴업시작일자    float64
#  13  휴업종료일자    float64
#  14  재개업일자     float64
#  15  소재지전화     object
#  16  소재지면적     float64
#  17  소재지우편번호   object
#  18  소재지전체주소   object
#  19  도로명전체주소   object
#  20  도로명우편번호   float64
#  21  사업장명      object
#  22  최종수정시점    object
#  23  데이터갱신구분   object
#  24  데이터갱신일자   object
#  25  업태구분명     object
#  26  좌표정보(x)   float64
#  27  좌표정보(y)   object
# dtypes: float64(7), int64(4), object(17)
# memory usage: 449.8+ MB

# %%
df8
# Out:
#             번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 0            1  휴게음식점  07_24_05_P   3670000  3670000-104-2023-00335
# 1            2  휴게음식점  07_24_05_P   3140000  3140000-104-2023-00222
# 2            3  휴게음식점  07_24_05_P   3140000  3140000-104-2023-00221
# 3            4  휴게음식점  07_24_05_P   4070000  4070000-104-2023-00180
# 4            5  휴게음식점  07_24_05_P   3070000  3070000-104-2023-00181
# ...        ...    ...         ...       ...                     ...
# 550145  550146  휴게음식점  07_24_05_P   3610000  3610000-104-2018-00018
# 550146  550147  휴게음식점  07_24_05_P   3610000  3610000-104-2018-00027
# 550147  550148  휴게음식점  07_24_05_P   3610000  3610000-104-2018-00031
# 550148  550149  휴게음식점  07_24_05_P   3610000  3610000-104-2017-00085
# 550149  550150  휴게음식점  07_24_05_P   3600000  3600000-104-2010-00022
#
#              인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  \
# 0       2023-09-22      NaN         3     폐업         2  ...
# ...

# %%
# df7 = df7.dropna(subset = ['도로명전체주소'])

# %%
# df8 = df8.dropna(subset = ['도로명전체주소'])

# %%
seoul_1 = df7[df7['소재지전체주소'].str.contains('서울특별시') | df7['도로명전체주소'].str.contains('서울특별시')]

# %%
seoul_2 = df8[df8['소재지전체주소'].str.contains('서울특별시') | df8['도로명전체주소'].str.contains('서울특별시')]

# %%
seoul_1
# Out:
#               번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 8              9  일반음식점  07_24_04_P   3070000  3070000-101-2023-00323
# 46            47  일반음식점  07_24_04_P   3160000  3160000-101-2023-00328
# 48            49  일반음식점  07_24_04_P   3230000  3230000-101-2023-00741
# 58            59  일반음식점  07_24_04_P   3060000  3060000-101-2023-00266
# 67            68  일반음식점  07_24_04_P   3140000  3140000-101-2023-00273
# ...          ...    ...         ...       ...                     ...
# 2073906  2073907  일반음식점  07_24_04_P   3110000  3110000-101-2020-00283
# 2073907  2073908  일반음식점  07_24_04_P   3110000  3110000-101-2020-00281
# 2073908  2073909  일반음식점  07_24_04_P   3110000  3110000-101-2020-00280
# 2074038  2074039  일반음식점  07_24_04_P   3040000  3040000-101-2020-00276
# 2075326  2075327  일반음식점  07_24_04_P   3150000  3150000-101-2020-00449
#
#               인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  \
# 8        2023-09-22      NaN         3     폐업         2  ...
# ...

# %%
seoul_2
# Out:
#             번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 1            2  휴게음식점  07_24_05_P   3140000  3140000-104-2023-00222
# 2            3  휴게음식점  07_24_05_P   3140000  3140000-104-2023-00221
# 4            5  휴게음식점  07_24_05_P   3070000  3070000-104-2023-00181
# 18          19  휴게음식점  07_24_05_P   3210000  3210000-104-2023-00304
# 22          23  휴게음식점  07_24_05_P   3010000  3010000-104-2023-00243
# ...        ...    ...         ...       ...                     ...
# 541190  541191  휴게음식점  07_24_05_P   3130000  3130000-104-2016-00382
# 541372  541373  휴게음식점  07_24_05_P   3030000  3030000-104-2023-00018
# 541547  541548  휴게음식점  07_24_05_P   3160000  3160000-104-2020-00100
# 543021  543022  휴게음식점  07_24_05_P   3210000  3210000-104-2020-00212
# 543022  543023  휴게음식점  07_24_05_P   3210000  3210000-104-2020-00213
#
#              인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  \
# 1       2023-09-22      NaN         3     폐업         2  ...
# ...

# %%
seoul = pd.concat([seoul_1, seoul_2])

# %%
seoul
# Out:
#             번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호  \
# 8            9  일반음식점  07_24_04_P   3070000  3070000-101-2023-00323
# 46          47  일반음식점  07_24_04_P   3160000  3160000-101-2023-00328
# 48          49  일반음식점  07_24_04_P   3230000  3230000-101-2023-00741
# 58          59  일반음식점  07_24_04_P   3060000  3060000-101-2023-00266
# 67          68  일반음식점  07_24_04_P   3140000  3140000-101-2023-00273
# ...        ...    ...         ...       ...                     ...
# 541190  541191  휴게음식점  07_24_05_P   3130000  3130000-104-2016-00382
# 541372  541373  휴게음식점  07_24_05_P   3030000  3030000-104-2023-00018
# 541547  541548  휴게음식점  07_24_05_P   3160000  3160000-104-2020-00100
# 543021  543022  휴게음식점  07_24_05_P   3210000  3210000-104-2020-00212
# 543022  543023  휴게음식점  07_24_05_P   3210000  3210000-104-2020-00213
#
#              인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  \
# 8       2023-09-22      NaN         3     폐업         2  ...
# ...

# %%
seoul.to_csv('서울음식점통합.csv', index=False)

# %%
seoul = pd.read_csv('서울음식점통합.csv', encoding='cp949')
# Out:
# C:\Users\akdhk\AppData\Local\Temp\ipykernel_8868\99910022.py:1: DtypeWarning: Columns (11,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   seoul = pd.read_csv('서울음식점통합.csv', encoding='cp949')

# %%
seoul.shape
# Out:
# (624129, 28)

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 624129 entries, 8 to 543022
# Data columns (total 28 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   번호        624129 non-null  int64
#  1   개방서비스명    624129 non-null  object
#  2   개방서비스아이디  624129 non-null  object
#  3   개방자치단체코드  624129 non-null  int64
#  4   관리번호      624129 non-null  object
#  5   인허가일자     624129 non-null  object
#  6   인허가취소일자   0 non-null       float64
#  7   영업상태구분코드  624129 non-null  int64
#  8   영업상태명     624129 non-null  object
#  9   상세영업상태코드  624129 non-null  int64
#  10  상세영업상태명   624129 non-null  object
#  11  폐업일자      459946 non-null  object
#  12  휴업시작일자    0 non-null       float64
#  13  휴업종료일자    0 non-null       float64
#  14  재개업일자     0 non-null       float64
#  15  소재지전화     368414 non-null  object
#  16  소재지면적     581689 non-null  float64
#  17  소재지우편번호   624120 non-null  object
#  18  소재지전체주소   624129 non-null  object
# ...

# %%
seoul = seoul.drop(['번호', '개방서비스아이디'], axis=1)
# Out:
#        개방서비스명  개방자치단체코드                    관리번호       인허가일자  인허가취소일자  \
# 8       일반음식점   3070000  3070000-101-2023-00323  2023-09-22      NaN
# 46      일반음식점   3160000  3160000-101-2023-00328  2023-09-22      NaN
# 48      일반음식점   3230000  3230000-101-2023-00741  2023-09-22      NaN
# 58      일반음식점   3060000  3060000-101-2023-00266  2023-09-22      NaN
# 67      일반음식점   3140000  3140000-101-2023-00273  2023-09-22      NaN
# ...       ...       ...                     ...         ...      ...
# 541190  휴게음식점   3130000  3130000-104-2016-00382  2016-11-18      NaN
# 541372  휴게음식점   3030000  3030000-104-2023-00018  2023-01-31      NaN
# 541547  휴게음식점   3160000  3160000-104-2020-00100  2020-08-03      NaN
# 543021  휴게음식점   3210000  3210000-104-2020-00212  2020-08-03      NaN
# 543022  휴게음식점   3210000  3210000-104-2020-00213  2020-08-03      NaN
#
#         영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명        폐업일자  ...  \
# 8              3     폐업         2      폐업  2023-10-15  ...
# ...

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 624129 entries, 8 to 543022
# Data columns (total 26 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   개방서비스명    624129 non-null  object
#  1   개방자치단체코드  624129 non-null  int64
#  2   관리번호      624129 non-null  object
#  3   인허가일자     624129 non-null  object
#  4   인허가취소일자   0 non-null       float64
#  5   영업상태구분코드  624129 non-null  int64
#  6   영업상태명     624129 non-null  object
#  7   상세영업상태코드  624129 non-null  int64
#  8   상세영업상태명   624129 non-null  object
#  9   폐업일자      459946 non-null  object
#  10  휴업시작일자    0 non-null       float64
#  11  휴업종료일자    0 non-null       float64
#  12  재개업일자     0 non-null       float64
#  13  소재지전화     368414 non-null  object
#  14  소재지면적     581689 non-null  float64
#  15  소재지우편번호   624120 non-null  object
#  16  소재지전체주소   624129 non-null  object
#  17  도로명전체주소   332924 non-null  object
#  18  도로명우편번호   328315 non-null  float64
# ...

# %%
seoul.rename(columns={'영업상태구분코드':'영업상태코드', '소재지전화':'전화번호', '소재지전체주소':'지번주소', '도로명전체주소':'도로명주소', '최종수정시점':'최종수정일자', '좌표정보(x)':'좌표정보(X)', '좌표정보(y)':'좌표정보(Y)'}, inplace=True)

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 624129 entries, 8 to 543022
# Data columns (total 26 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   개방서비스명    624129 non-null  object
#  1   개방자치단체코드  624129 non-null  int64
#  2   관리번호      624129 non-null  object
#  3   인허가일자     624129 non-null  object
#  4   인허가취소일자   0 non-null       float64
#  5   영업상태코드    624129 non-null  int64
#  6   영업상태명     624129 non-null  object
#  7   상세영업상태코드  624129 non-null  int64
#  8   상세영업상태명   624129 non-null  object
#  9   폐업일자      459946 non-null  object
#  10  휴업시작일자    0 non-null       float64
#  11  휴업종료일자    0 non-null       float64
#  12  재개업일자     0 non-null       float64
#  13  전화번호      368414 non-null  object
#  14  소재지면적     581689 non-null  float64
#  15  소재지우편번호   624120 non-null  object
#  16  지번주소      624129 non-null  object
#  17  도로명주소     332924 non-null  object
#  18  도로명우편번호   328315 non-null  float64
# ...

# %%
bakery = pd.read_csv('data/제과점.csv', encoding='cp949')

# %%
bakery = bakery.drop(bakery.columns[25:44], axis=1)

# %%
# bakery.insert(0, '개방서비스명', '제과점')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 bakery2.insert(0, '개방서비스명', '제과점')
#
# AttributeError: 'NoneType' object has no attribute 'insert'

# %%
bakery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13940 entries, 0 to 13939
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방서비스명    13940 non-null  object
#  1   개방자치단체코드  13940 non-null  int64
#  2   관리번호      13940 non-null  object
#  3   인허가일자     13940 non-null  object
#  4   인허가취소일자   0 non-null      float64
#  5   영업상태코드    13940 non-null  int64
#  6   영업상태명     13940 non-null  object
#  7   상세영업상태코드  13940 non-null  int64
#  8   상세영업상태명   13940 non-null  object
#  9   폐업일자      9873 non-null   object
#  10  휴업시작일자    0 non-null      float64
#  11  휴업종료일자    0 non-null      float64
#  12  재개업일자     0 non-null      float64
#  13  전화번호      6806 non-null   object
#  14  소재지면적     12892 non-null  object
#  15  소재지우편번호   13906 non-null  object
#  16  지번주소      13907 non-null  object
#  17  도로명주소     9920 non-null   object
#  18  도로명우편번호   9813 non-null   float64
#  19  사업장명      13940 non-null  object
# ...

# %%
bakery = bakery[bakery['지번주소'].str.contains('서울특별시') | bakery['도로명주소'].str.contains('서울특별시')]

# %%
bakery
# Out:
#       개방서비스명  개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  \
# 0        제과점   3220000  3220000-121-2023-00040  2023-04-04      NaN       1
# 1        제과점   3240000  3240000-121-2017-00026  2017-08-14      NaN       1
# 2        제과점   3230000  3230000-121-2017-00031  2017-08-14      NaN       3
# 3        제과점   3220000  3220000-121-2023-00041  2023-04-04      NaN       3
# 4        제과점   3180000  3180000-121-2023-00032  2023-06-19      NaN       1
# ...      ...       ...                     ...         ...      ...     ...
# 13935    제과점   3220000  3220000-121-2022-00129    20221230      NaN       3
# 13936    제과점   3210000  3210000-121-2023-00001    20230102      NaN       1
# 13937    제과점   3220000  3220000-121-2021-00096    20211220      NaN       3
# 13938    제과점   3210000  3210000-121-2022-00081    20221229      NaN       3
# 13939    제과점   3180000  3180000-121-2019-00017    20190816      NaN       3
#
#        영업상태명  상세영업상태코드 상세영업상태명        폐업일자  ...  \
# ...

# %%
all = pd.concat([seoul, bakery])

# %%
all.shape
# Out:
# (638034, 26)

# %%
all.to_csv('통합.csv', index=False)

# %%
all
# Out:
#       개방서비스명  개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  \
# 8      일반음식점   3070000  3070000-101-2023-00323  2023-09-22      NaN       3
# 46     일반음식점   3160000  3160000-101-2023-00328  2023-09-22      NaN       3
# 48     일반음식점   3230000  3230000-101-2023-00741  2023-09-22      NaN       3
# 58     일반음식점   3060000  3060000-101-2023-00266  2023-09-22      NaN       3
# 67     일반음식점   3140000  3140000-101-2023-00273  2023-09-22      NaN       3
# ...      ...       ...                     ...         ...      ...     ...
# 13935    제과점   3220000  3220000-121-2022-00129    20221230      NaN       3
# 13936    제과점   3210000  3210000-121-2023-00001    20230102      NaN       1
# 13937    제과점   3220000  3220000-121-2021-00096    20211220      NaN       3
# 13938    제과점   3210000  3210000-121-2022-00081    20221229      NaN       3
# 13939    제과점   3180000  3180000-121-2019-00017    20190816      NaN       3
#
#        영업상태명  상세영업상태코드 상세영업상태명        폐업일자  ...  \
# ...

# %%
# 열 선택하기
df['열 이름']

# %%
# 여러 개의 열 선택하기
df[['열 이름 1', '열 이름 2', ...]]

# %%
# 열에 있는 유일한 값을 넘파이 array 형태로 출력
df.열이름.unique() 또는 df['열이름'].unique()

# 열에 있는 유일한 값과 각 값 별로 개수를 판다스 series 형태로 출력
df.열이름.value_counts() 또는 df['열이름'].value_counts()

# %%
# 행 선택하기
df.loc[행 이름 또는 인덱스]

# %%
# 여러 개의 행 선택하기
df.loc[[행 이름 또는 인덱스 1, 행 이름 또는 인덱스 2, ...]]

# %%
# 2010년 이후의 데이터만 선택하기
df[df['Year'] >= 2010]

# %%
# 2010년 이후이면서 금메달 이상을 획득한 데이터만 선택하기
df[(df['Year'] >= 2010) & (df['Medal'] == 'Gold')]

# %%
# 'KOR', 'USA', 'JPN' 국가의 데이터만 선택하기
df[df['NOC'].isin(['KOR', 'USA', 'JPN'])]

# %%
# groupby() 함수 이용하기
df.groupby('열 이름')

# %%
# 집계 함수 이용하기
그룹화된 데이터.집계함수()

# %%
# 국가별 금메달 수의 합계 구하기
df[df['Medal'] == 'Gold'].groupby('NOC')['Medal'].count()

# %%
# 내림차순으로 정렬하기
df.sort_values('열 이름', ascending=False)

# %%
# 특정 열 null 개수 조회하기
df.열이름.isnull().sum()
df['열이름'].isnull().sum()

# %%
# A열에서 10인 값의 개수
len(df.loc[df['A'] == 10])
