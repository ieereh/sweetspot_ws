# %%
import time
import random
import pyperclip
import platform
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import NoSuchElementException

# %%
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])
chrome_options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36')

# %%
service = Service(executable_path=r'C:/Users/Puser/Workspace/chromedriver.exe')

# %%
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
url1 = "https://twitter.com/search"

# %%
id = "hyunjiye0821"
pwd = "zhdvld2Wkd!"

# %% [markdown]
# ### 로그인

# %%
def login(id, pwd, url) :
    isSuccess = False
    platform.system() # 운영체제 확인
    copy_key = ''
    if platform.system() == 'Windows' :
        copy_key = Keys.CONTROL
    else:
        copy_key = Keys.COMMAND
        
    driver.get(url)
    time.sleep(5)
    
    try:
        driver.find_element(By.XPATH,'//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[5]/label/div/div[2]/div/input').click()
        pyperclip.copy(id)
        ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
        time.sleep(2)
        driver.find_element(By.XPATH,
                                      '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[6]/div').click()
        
        time.sleep(3)
        driver.find_element(By.XPATH,'//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[3]/div/label/div/div[2]/div[1]/input').click()
        pyperclip.copy(pwd) 
        ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
        try:
            login_btn = driver.find_element(By.XPATH , '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div/span/span')
            login_btn.click()
            time.sleep(3)
            isSuccess = True
        except Exception as e:
            print(f"twitter submit, cookies save failed : {e}")
            pass
            
    except Exception as e:
        print(f"twitter login input id, password failed : {e}")
        isSuccess = True
        pass
    

    return isSuccess

# %% [markdown]
# ### 지역명 키워드 리스트 (여의도, 종로)

# %%
locations = ["여의도", "국회의사당", "여의나루", "더현대", "여의도한강공원",
             "종로", "익선", "혜화", "부암동", "평창동", "삼청동", "인사동", "대학로", "경복궁",
             "서촌", "북촌", "종각", "동묘", "광화문", "가회", "안국", "광장시장", "낙산공원",
             "서순라길", "정동", "효자동", "덕수궁", "창신동", "창덕궁"]

# %%
locations = ["익선동"]

# %% [markdown]
# ### 해시태그셋 리스트

# %%
hashtags = ["#승연아_우즈야_여기야 OR #신동_넌이미먹었겠지 OR #박지성_단1g도안줌 OR #제노의_맛그당어 OR #런쥔이_밥무거쒀 OR #확신해찬맛집 OR #몬베베가_몬베베에게_추천하는_맛집 OR #백현이를_위한_맛집투어 OR #황제님을위한메뉴판 OR #강다니엘_염염긋 OR #완전_장원영_스타일_아니냐구 OR #ㄷㅂㅇㅈ OR #런쥔이의_맛집내비게이션 OR #승철이_이거먹고_볼빵빵했꾸마 OR #정한아_마니머거여ㅎㅎ OR #조슈아_먹어보슈아 OR #순영아_이거_맛있어 OR #원우야_여기_테이스티 OR #민규라고치고_디너쇼해도돼 OR #도겸이도_도아할_맛집 OR #믿고먹어boo세요", 
           "#남도현_한입도안줄래 OR #재민아_밥먹어 OR #은하야_이거_맛있어 OR #지우야_맛집은여기 OR #우석아_맛집으로_우따따따 OR #도겸아_여기야_피자대동여지도 OR #잘_먹고_잘_사는_순딩이 OR #주헌아_잡솨_바바요 OR #펜타곤함께먹자 OR #백현이를_위한_레시피_공유 OR #백현이를_위한_맛집_투어 OR #민석이를_위한_카페투어 OR #민석이를_위한_빵집투어 OR #강동호_먹어봐 OR #세훈이의_여행을_떠나요 OR #백현이를_위한_일본투어 OR #먹어봤도영 OR #황제를위한메뉴판 OR #동현이를_위한_대동맛지도 OR #정우의_원데이식스밀 OR #정우의_원데이씩스밀 OR #먹다가_해찬이_생각이나신거예요 OR #마크한테만_공개 OR #성찬이의_진수성찬 OR #기현_너는맘마먹고다시시작하겠지 OR #아이유애냐미냐미 OR #더보이즈_배고플땐언제든찾아와요 OR #크리스_배고파용", 
           "#리노는_배고파 OR #창빈이는_안보겠지ㅠ OR #현이도_먹어봐 OR #한이의한입거리 OR #이_식당은_진심으로_하늘이에요 OR #여기맛있승민 OR #아기빵_크림채워 OR #eaj_말구_eatj OR #나는_너의_밥선생 OR #영현아_여기서도_7인분_어때 OR #나나나나_원필이가_먹을래 OR #도운이_밥묵엇슴까 OR #우리배는_식도로만_가 OR #이게바로_에이티즈의_맛인기라 OR #아니예요_준휘는_먹을거예요 OR #우지를삼킬순없잖아 OR #밍하오야_여기_헌하오츠 OR #THE_ATE OR #버논아_혹시여긴_맛집 OR #라즈지 OR #디노야_여기_케이밥의_미래 OR #캐럿들_여기_캐맛있어 OR #계산은_쿱스가 OR #위EAT_인EAT OR #승윤이의_맛집_PAGE OR #쭈대장과_함께", 
           "#이맛집_찐받네 OR #마이노_마이무 OR #훈슐랭_여기도가봤니 OR #야빠들도_맛있는거먹어 OR #황대인_넌_이미_단골이겠지 OR #먹으러갸자 OR #갸영철_여긴_꼭_먹어라 OR #경수야_여기가_맛집이디오 OR #곤_만나서_먹자 OR #병곤아_이거_곤나맛있어 OR #승훙이도_훙입만 #먹어보세용_희희 OR #아강이_냐미냐미 OR #현석아_이거_머거바니 OR #서기의_메뉴판 OR #삼킬듯한 OR #배지니욘나_맛집 OR #너무맛있어서픽스러짐 OR #맛있겠짛_주연앟 OR #이주연_난늘배고파_베베 OR #이재현_치킨이_다가아니야 OR #어이어이_이재현_여기다 OR #영훈아_밥좀많이먹어라 OR #재현아_차츰공복이드리울테니 OR #영훈아_빵빵하게_먹어 OR #NewFoodshot OR #최찬희_요정은_밥심이다 OR #지창민_도토리대신 OR #지창민_떡볶이말고_이건_어때 OR #뱀맛집 OR #배무맛집 OR #퉤이스티로드 OR #왕잭슨_여기_왕맛있다 OR #냠긔탱긔 OR #세훈아_이거봐라_맛있겠지 OR #드셔보세훈 OR #세훈이_세입먹을때_세프는_세그릇째 OR #세훈아_순댓국_말고_이거 OR #소원아여기가거기야 OR #맛린집 OR #은하에게_강추 OR #유주라잌썸띵투잍 OR #맛이신비해 OR #무지야여기무지맛있어 OR #여기먹어볼새롬 OR #문익아_여기서_파는거야 OR #먹잘알_종형아_이거_먹잘 OR #기석이_밥_먹을_시간 OR #재찬아_밥먹자 OR #먹어보시갱 OR #꼬르륵소리 OR #배부르다현 OR #상아야_여기_맛집_맞지", 
           "#원상아_여기_알라빙빙 OR #셔누_넌이미먹었겠지만또먹어야겠지 OR #민혁_너는이미북마크해놨겠지 OR #기현_너는맘마먹고다시시작하겠지 OR #채형원_너는세입도못먹겠지 OR #주헌_너는한입가득못먹겠지 OR #임창균_너는한끼뚝닭먹겠지 OR #웅이가_맛보면_좋겠웅 OR #우진아_맛집_추천_별거아냐 OR #동현이를_위한_대동맛지도 OR #대휘가_먹으면_아맛나 OR #지젤아밥무라 OR #윈터의_맛집을_입력해주세요 OR #닝닝이랑같이먹고싶은거 OR #지구에서여기가젤루맛있어 OR #이맛집은신이에요 OR #우리배는_식도로만_가 OR #에이티즈_우리배는_식도로만_가 OR #이게바로_에이티즈의_맛인기라 OR #이타다끼_마쓰 OR #박성화_세입컷챌린지 OR #왕맛있슨 OR #대열아_여기가맛있대열 OR #와이_렇게맛있을수가 OR #장준아나중에밥이나한끼하자 OR #태그야_맛집해시태그야 OR #승민아_여기_z지존킬z OR #봉재현_이건_먹겠지 OR #지범_맛집다녀오겠습니다 OR #주찬아_쫓겨나기전까지만먹자 OR #주찬_넌이미여기서쫓겨났겠지 OR #동동맛집센터 OR #보민아_여기가극락인가봄 OR #Y가_최고로_모시는_맛집 OR #캐럿들_여기_캐맛있어 OR #세운아_먹어보세운 OR #이맛이꾸민지생시인지 OR #맛집으로달려라하니 OR #단다니챙겨먹자 OR #난맛집을찾는_베이비 OR #혜인아_다음에꼭같이가자 OR #손영재_콧구멍_커지겠지 OR #주현아맛있겠찌 OR #슬슐랭가이드 OR #오늘은웬디여기 OR #수영아아줌마들잘먹지 OR #누가_날_맛집으로_땡긴다악 OR #연히의_냠냐미 OR #여기수윤이자린데오", 
           "#NJ맛집_맞지 OR #드댕이도_드냠드냠 OR #협아_이_디저트꼭먹어봐 OR #윤성아_혼자_먹기_아까워 OR #주창욱_넌_안먹어봤겠지 OR #동윤아_맛집은_안중요한가 OR #민서가_쏠테니_많이먹어 OR #집중집중_준호_맘마타임 OR #준호야_맛있는_거_먹으러_가차 OR #이_거맛있어_협 OR #렉스에게_가장_잘맞는_맛집은 OR #영현아_여기서도_7인분_어때 OR #경윤아_여기_찐맛이야 OR #AI_충전기 #민규_이거_먹어 OR #박성화_너는세입이면먹겠지 OR #박성화_이것좀_먹어보라고_성화 OR #캡틴홍중의_다음_먹적지 OR #김홍_중독될정도로맛있는집 OR #정윤_호불어서먹어 OR #정윤_호텔5성안부럽다 OR #정윤_호텔5성뷔페안부럽다 OR #윤둥아_이거_둥나맛있어 OR #맛이여_상상이상 OR #강여_상당히맛있는집 OR #강여상_치킨말고_이것도_먹어봐 OR #산맛집 OR #산이미식회 OR #여기도_먹어보산 OR #오늘도_잘먹었산 OR #최산을_다해_먹어봐요 OR #송민_기가막힌맛집 OR #맛있게_먹우영 OR #정우영_한입에_먹우영 OR #정우_영원히먹을수있는집 OR #쫑슐랭가이드 OR #찍먹보단쫑먹 OR #최종_호불호없는맛집 OR #최종호_먹어봐_최종보스_맛집 OR #VJ_윤호특공대 OR #김선우_맛있는걸내가놔둘리가 OR #몽아_몽먹었니 OR #캐럿들_여기_캐맛있어 OR #수아_여기_와봤수아 OR #여기와봤_수아 OR #뚜현아_진짜_여기_맛집이야 OR #뚜진맛 OR #수현아_밥먹자 OR #먹잘알람 OR #라미_완소한끼 OR #츠키_많이먹어 OR #츠키야당근말고이거 OR #수연이랑_냥냥멍냠 OR #션이랑_냠냠멍냠 OR #이거먹자_시윤아 OR #이거먹어볼래_시윤아 OR #오늘도_냠냠하루나 OR #하루나_여기맛집이야 OR #Oneday_나의까까 OR #블랙핑크_맛집사거리 OR #제니야_여기젠나마싯다 OR #채영아_눈물나는맛이야 OR #지수야_여기츄라이츄라이 OR #리사에게_가장맛난걸로줘 OR #천러야_이거_먹기좋아 OR #은광아_이거_누룽지백숙만큼_맛있어 OR #여기_도토리 OR #창섭아_맛집어디있는지알게됐됬됐됬됐다", 
           "#현식적인맛집추천 OR #이거맛있뎨 OR #창섭아_여기맛있섭 OR #남준아여기째끼럽 OR #문득생각해석진이가이걸먹어봤을까 OR #머거스트디 OR #야호바너이거먹어봤냐 OR #지민이와_밥밥밥을먹어요 OR #뷔슐랭 OR #정국아_같이먹짱 OR #효앞꾸먹 OR #병근한입 OR #휘랑둥_여긴가야해 OR #석원이도냠냠 OR #이타_다끼마스 OR #편식쟁이_원이_먹어봐 OR #현빈아_난_먹어봤지롱 OR #도환아_여기와서_먹어봐 OR #맛집을_태그 OR #크래비티_무뿌식뿌 OR #나_한입_세림이_세입 OR #앨런아_맛집으로_지금_당장_런 OR #정모야_맛집_뒤집자 OR #우빈아_데굴데굴_냠 OR #원진아_함번만_먹어봐 OR #미니미니미니_강쥐는먹으면안돼용 OR #형준아_내랑_밥물래 OR #태영이도_맛집_태워가영 OR #성민이_입에_안성맞춤 OR #엔진예절 OR #엔진이_커넥해주는_맛집 OR #가든_맛집 OR #정원이_볼살로_레쭈고 OR #맛있떠_누가만들었어이거 OR #정원이의_식사랜드 OR #당연함_이희승이먹어야함 OR #희승아_라면말고_이건어때 OR #오늘의_제이 OR #맛집_기대해주셔도_감사합니다 OR #재윤이에게_메뉴추천 OR #제이크_요기요 OR #성훈이_입속으로_트리플악셀 OR #선우도_가고싶어하는_맛집 OR #선우야_이것도_맛있을거예요 OR #니시무라_마니무라 OR #민석아금강산도식후경 OR #민석아_여기가_맛집이슈 OR #준면아_여기_준맛탱 OR #백현아_먹짱일기_적짱 OR #됴슐랭 OR #경수야_먹어됴 OR #종인아_잘먹을게 OR #종인아또나만먹는거지 OR #맛집_추천해주세훈", 
           "#하영아_진짤루_맛집잉엥용 OR #맛집을_규와앙 OR #지원아밥메건니 OR #지선아_누가1인분만먹고살아_미친거지 OR #역시_대나무가_아니면_곤란한가요_더여나 OR #우리_챙람쥐_식량저장소 OR #나경아_여기맛집웅앵 OR #꿀깅아_여기_꿀발랐다 OR #이식당놓쳐서후회한다면후회한시간을후회할거잖아후회하기싫음후회할일들을후회하기전에_이거먹어봐 OR #지나니_이거맛나니 OR #바비야밥이왔어요 OR #윤형아_여기맛집이햫 OR #준회야_여기밥많이주내 OR #찬우야여기맛집이_왔쨔뇨 OR #김동동_일단밥부터먹혁 OR #어_리안이가_리안이가 OR #미래에_갔다왔는데_맛집_돼_있던_맛집 OR #도도의_맛집여행 OR #카엘아_여기야 OR #동표야_넌이거못먹지 OR #시영이가_생각나면_올릴게요 OR #장유빈_멋있고_귀여운_막내온탑 OR #재혀니_맛있게머겅 OR #정우의_원데이씩스밀 OR #도영이의유맹맛집 OR #태용아_먹어보태용 OR #존맛툥구리 OR #JMTforTAEIL OR #먹태일_기릿 OR #태일아_먹어봐 OR #맛있었쟈니 OR #먹으러가쟈니 OR #먹어봤쟈니 OR #체리모토랑_맛집_같이_하겠다 OR #윈윈_먹으라고_알랑방구 OR #먹으면_서로_윈윈 OR #悠太_味확인맛집 OR #유타_味확인맛집 OR #우와_저맛집유맹해 OR #마크한테만공개 OR #나나의_맛집탐방기 OR #나나챌린지 OR #맛집사냥쿤 OR #이거맛있쿤 OR #食中食_TEN OR #모든식당텐기다려줘방문할게 OR #샤오쥔_광둥타코말고_이거먹어봐 OR #덕준아_이세상엔_맛있는게많다 OR #헨드리_맛도리 OR #헨드리_안먹으면_후회한드리 OR #양양아_념념하자 OR #양양_먹어봐_얌얌 OR #먹어봤_쇼타로 OR #튼튼하게_먹지성 OR #승짱JMT니까먹어봐 OR #차훈_넌어차피_안먹겠지 OR #재현아_맛있겠지_김재현이요 OR #회승아_만들수있니_집밥요정 OR #동동아_먹어봐 OR #오소스_소스에_찍어_먹어 OR #알리오소스_아니고_저스트_오소스 OR #레이븐이_가봐야할_이쁜_맛집 OR #서호야_호호불어먹어 OR #궈낙아_이거머궈봐 OR #건학아_이거만먹고_운동할게 OR #건희를_위한_추천맛집", 
           "#환웅아이거먹고사람될게 OR #내동주고_사먹은_맛집후기 OR #용훈이_얼굴만큼_기대하고가도되는곳 OR #강건너_현구맛집 OR #kang_981124 OR #ㅎㄹㅇㅌㄱㅂ OR #하린아_자셔봐 OR #동명이_배고파 OR #기욱이의_볼주머니_저장창고 OR #효진이는_앞으로도_꾸준히먹자 OR #효앞꾸먹 OR #효지나마이크내리고젓가락들어 OR #이션같이찌자 OR #이같찌 OR #창윤아내가다계산할게먹기만해 OR #먹어야살어 OR #이승준먹방대결 OR #어스_맛집_여기있으 OR #수박민균 OR #민균이를위한야미푸드 OR #엇대먹 OR #꺼야미야미 OR #유토와_같이먹자 OR #맛집소개해줄게Ü OR #인성아나이거오분순삭 OR #영균아_뭐라도_먹어봐 OR #저는잘먹을수있어요 OR #얘두다나이거먹음 OR #김석우_입으로_떼구르르 OR #옴뇸뇸소리안나요 OR #태양아_이거어때_난좋은데 OR #함께먹어주호 OR #영빈아왜먹질못하니 OR #기범아_나혼자먹는거_아니야 OR #종현아_우린_대왕쁘띠가될거야 OR #민호야_식단관리_이겨내 OR #태민_DO_EAT_BABY OR #찡기야_맛있겠찡 OR #릴프릭이_함냐함냐함 OR #크리스_배고파용 OR #창빈이는_안보겠지ㅠ OR #현이도_먹어봐 OR #한이의한입거리 OR #이_식당은_진심으로_하늘이에요 OR #현이도_먹어봐 OR #쏟아지는_맛집 OR #비니의맛집_마시쪄마시쪄 OR #수민아이거먹어 OR #수민아_이거먹어 OR #시은이의꿀맛보장 OR #아이사장님뭘좀아네 OR #맛집이세은 OR #맛집이윤 OR #재이야여기짱맛있어 OR #냠냠쭌쭌 OR #복숭아맛집 OR #성준아_여기_같이_오자 OR #오냠오냠 OR #휘로록짭짭 OR #낑깡현수 OR #휘풍당당_맛집_나가신다 OR #현석이_입맛이에 OR #지훈아_여기가봐라 OR #욧집 OR #준규_메롱 OR #마시호_여기가보시호", 
           "#재혁아_바나나우유말고_이것도먹어봐 OR #사히맛집태그언제생겨 OR #사히밥 OR #예담아_담아놔 OR #이야아마시따아도영아 OR #정우야_여기_먹으러_꼭와 OR #라마x3 OR #정환아_여기맛있소 OR #쩝쩝박사_말랑이에게 OR #지효야나먹어쪄 OR #사나없이먹으나마나 OR #최연준_맛집1등어디야 OR #연도먹_연준이도먹어 OR #연준아_여기_으악으엑 OR #수빈아_먹어봐_마수리수리 OR #범규야_제발_한입만_먹어봐 OR #태현아_한번_맛볼테리 OR #태현이의_소식먹방 OR #강이사님_드셔보세요 OR #휴닝이는_맛있는거_먹고심분딩 OR #휴닝이_배고파요 OR #휴닝아먹어봐_백퍼카이취향 OR #투모로우바이투게더_먹어봐 OR #허나아_밥먹자 OR #호영씨_아아아아 OR #민찬아_만찬이야 OR #계현보장맛집 OR #여노야_밥은_먹고_다니니 OR #용왕님_기미상궁_마쳤어용승 OR #이게내마지막밥이라고 OR #너에게내밥상을줄게 OR #상엽아_다람쥐는_이거_못먹겠지 OR #휘연이와_함께하고싶은_곳 OR #지냥이_배고파", 
           "#kcal_플랙스 OR #펜타곤_같이먹자 OR #홍석_넌_먹으면_근손실오겠지 OR #여기바로고민보다고_신원 OR #펜타곤에서제일베부른정우석 OR #형구야_여기_완전_기가막키노 OR #후_이거먹으러_와라_회택아 OR #개밥보다맛있는몽몽이밥 OR #여기넘맛있어유_또올래 OR #이거먹고다이어트_조지노 OR #예_난여기로정했다 OR #택운이를_위한_뮤슐랭가이드 OR #학연이가_뇸뇸_먹어볼까욘 OR #라비_맛집_도와드려요 OR #갈비찜을밥위에얹어주세횩 OR #쟌이뭐먹어 OR #밥먹었어요_아니요 OR #고뚠아_이거먹어봐 OR #도시야_이거_억수로_맛있데이 OR #수안이가_행복해지려면_이걸먹어봐 OR #이거무디맛있어 OR #사회인먹짱클럽 OR #THIS_IS_EAT OR #명준이_아가배_지킴단 OR #진우야_이거다_이거맛있지누 OR #빈아_운동및식단_포기했다 OR #돌잔치_음식추천 OR #로하_이거먹으러_왔따나 OR #은우야_인누와_같이먹차 OR #두준아나두먹을래 OR #식샤님의_깨끗한_밥그릇 OR #식샤님_블로그_올리셨나요 OR #식샤님_오늘은_뭐드셨어요 OR #맛섭아_요집이야 OR #근손실도_이기구왕 OR #동운아_밥은먹고다니냐 OR #전영중_넌이미먹었겠지 OR #상호_밥_무라 OR #찬양이도_찬양하는맛집투어 OR #인간태풍_상륙 OR #맛이상당히준수하네요 OR #박병찬의_밥반찬 OR #누가계속맛집가래 OR #최종수_오른쪽으로가다가멈춰서젓가락질_막아봐 OR #너생각보다맛집이구나 OR #밥묵자부기 OR #아_하세혁 OR #종혁아_밥먹었니 OR #아빠_이거사줘 OR #맛있으면박솸번주쉐이 OR #가슴이웅덩해지는맛 OR #하오_늘도잘먹었다 OR #한빈이_입속으로_올인해 OR #석메추 OR #태래비전출연맛집 OR #우_리키_리만_먹자 OR #규비니랑_와규와규 OR #밥건욱 OR #유진아복숭아는에피타이저구 OR #먹다가_해찬이_생각이_나신거예요 OR #성규야_여기가_바로_맛집인뎁쇼 OR #유정이가_좋아하는_맛집_좀_추천해줄래 OR #밥먹었나영 OR #나영이랑_더_빠르게_맛집_찾아볼래요", 
           "#foodforboo OR #션프는셔누사랑만먹을게_갈비찜 OR #주학년_먹는데돈아끼지말자 OR #주학년_푸드플렉스 OR #학신 OR #금동아_이거먹고_세계정복 OR #상상그이상의_맛집 OR #여보세요_상연아_나_맛집이야_끊어 OR #쩸냠냥 OR #상프들_맛집은_신중해야해 OR #그거먹고_배가찬희 OR #단서_말고_맛집_찾자 OR #특별한_음식_특이에게_추천하기 OR #희철아_고양이는_이런거_못먹겠지 OR #맛집_규게좋은거야 OR #규가수에_규팬 OR #규현을_위한_맛집_만나러_간다 OR #내_위장이_움찔했던_순간 OR #고마운_려욱이에게_맛집추천 OR #은혁아_맛집_땡겨 OR #맛집으로_이동해 OR #설원대짜하나주세요 OR #케빈_내밥의반을줄게 OR #케빈_설렐때만_맛집이니까 OR #현재야_치킨이닭 OR #아땡마랑_같이먹자 OR #콥이는_콥빼기로주세요 OR #창균아_오늘의_일반식 OR #파랑한끼 OR #우무이 OR #Black항상잘먹음 OR #밥을먹는거아니었어감동을먹고있었어 OR #태어나서밥안먹어본사람처럼밥을먹었어 OR #냠냠쭉쭉 OR #이거먹으러카즈하 OR #자윤아여기맛있어 OR #태웅이를위한잠이확깨는맛집 OR #여기가_해피이한_맛집 OR #우즈야_무즈는_이거먹어 OR #더비예절 OR #캠든아_이거_캠맛있다 OR #원_없이먹어_빈아 OR #원빈이는기타쳐_난주문벨칠게 OR #실버램지의_추천 OR #민규야원우야_여기비럴스윗 OR #아땡마_잘먹지 OR #호랑이는_못먹겠지 OR #런쥔이왔당 OR #탱구야_여기존맛탱구리 OR #나인이가_아마_먹을_수_있을걸 OR #먹둥지말둥지 OR #재민아_우리_먹을때_같이가 OR #아니에요_준휘는_먹을거에요 OR #백현아오늘은 OR #돼지성_단1g도안줌 OR #인기현상_맛집해시_뭐였더라 OR #효랑단이_맛집_알려줄게효 OR #여기가_맛집으론_최고지호 OR #모승맛인지_궁금하지 OR #큥튜브_먹방 OR #황제님을_위한_메뉴판 OR #도나쓰_냠 OR #먹태일기릿 OR #밥먹었수호"]

# %% [markdown]
# ### 해시태그셋을 url에 붙일 형태로 변경

# %%
hashtags1 = []
for hashtag in hashtags:
    hashtag = hashtag.replace(" ", "%20")
    hashtag = hashtag.replace("#", "%23")
    hashtags1.append(hashtag)
print(hashtags1)
# Out:
# ['%23승연아_우즈야_여기야%20OR%20%23신동_넌이미먹었겠지%20OR%20%23박지성_단1g도안줌%20OR%20%23제노의_맛그당어%20OR%20%23런쥔이_밥무거쒀%20OR%20%23확신해찬맛집%20OR%20%23몬베베가_몬베베에게_추천하는_맛집%20OR%20%23백현이를_위한_맛집투어%20OR%20%23황제님을위한메뉴판%20OR%20%23강다니엘_염염긋%20OR%20%23완전_장원영_스타일_아니냐구%20OR%20%23ㄷㅂㅇㅈ%20OR%20%23런쥔이의_맛집내비게이션%20OR%20%23승철이_이거먹고_볼빵빵했꾸마%20OR%20%23정한아_마니머거여ㅎㅎ%20OR%20%23조슈아_먹어보슈아%20OR%20%23순영아_이거_맛있어%20OR%20%23원우야_여기_테이스티%20OR%20%23민규라고치고_디너쇼해도돼%20OR%20%23도겸이도_도아할_맛집%20OR%20%23믿고먹어boo세요', '%23남도현_한입도안줄래%20OR%20%23재민아_밥먹어%20OR%20%23은하야_이거_맛있어%20OR%20%23지우야_맛집은여기%20OR%20%23우석아_맛집으로_우따따따%20OR%20%23도겸아_여기야_피자대동여지도%20OR%20%23잘_먹고_잘_사는_순딩이%20OR%20%23주헌아_잡솨_바바요%20OR%20%23펜타곤함께먹자%20OR%20%23백현이를_위한_레시피_공유%20OR%20%23백현이를_위한_맛집_투어%20OR%20%23민석이를_위한_카페투어%20OR%20%23민석이를_위한_빵집투어%20OR%20%23강동호_먹어봐%20OR%20%23세훈이의_여행을_떠나요%20OR%20%23백현이를_위한_일본투어%20OR%20%23먹어봤도영%20OR%20%23황제를위한메뉴판%20OR%20%23동현이를_위한_대동맛지도%20OR%20%23정우의_원데이식스밀%20OR%20%23정우의_원데이씩스밀%20OR%20%23먹다가_해찬이_생각이나신거예요%20OR%20%23마크한테만_공개%20OR%20%23성찬이의_진수성찬%20OR%20%23기현_너는맘마먹고다시시작하겠지%20OR%20%23아이유애냐미냐미%20OR%20%23더보이즈_배고플땐언제든찾아와요%20OR%20%23크리스_배고파용', '%23리노는_배고파%20OR%20%23창빈이는_안보겠지ㅠ%20OR%20%23현이도_먹어봐%20OR%20%23한이의한입거리%20OR%20%23이_식당은_진심으로_하늘이에요%20OR%20%23여기맛있승민%20OR%20%23아기빵_크림채워%20OR%20%23eaj_말구_eatj%20OR%20%23나는_너의_밥선생%20OR%20%23영현아_여기서도_7인분_어때%20OR%20%23나나나나_원필이가_먹을래%20OR%20%23도운이_밥묵엇슴까%20OR%20%23우리배는_식도로만_가%20OR%20%23이게바로_에이티즈의_맛인기라%20OR%20%23아니예요_준휘는_먹을거예요%20OR%20%23우지를삼킬순없잖아%20OR%20%23밍하오야_여기_헌하오츠%20OR%20%23THE_ATE%20OR%20%23버논아_혹시여긴_맛집%20OR%20%23라즈지%20OR%20%23디노야_여기_케이밥의_미래%20OR%20%23캐럿들_여기_캐맛있어%20OR%20%23계산은_쿱스가%20OR%20%23위EAT_인EAT%20OR%20%23승윤이의_맛집_PAGE%20OR%20%23쭈대장과_함께', '%23이맛집_찐받네%20OR%20%23마이노_마이무%20OR%20%23훈슐랭_여기도가봤니%20OR%20%23야빠들도_맛있는거먹어%20OR%20%23황대인_넌_이미_단골이겠지%20OR%20%23먹으러갸자%20OR%20%23갸영철_여긴_꼭_먹어라%20OR%20%23경수야_여기가_맛집이디오%20OR%20%23곤_만나서_먹자%20OR%20%23병곤아_이거_곤나맛있어%20OR%20%23승훙이도_훙입만%20%23먹어보세용_희희%20OR%20%23아강이_냐미냐미%20OR%20%23현석아_이거_머거바니%20OR%20%23서기의_메뉴판%20OR%20%23삼킬듯한%20OR%20%23배지니욘나_맛집%20OR%20%23너무맛있어서픽스러짐%20OR%20%23맛있겠짛_주연앟%20OR%20%23이주연_난늘배고파_베베%20OR%20%23이재현_치킨이_다가아니야%20OR%20%23어이어이_이재현_여기다%20OR%20%23영훈아_밥좀많이먹어라%20OR%20%23재현아_차츰공복이드리울테니%20OR%20%23영훈아_빵빵하게_먹어%20OR%20%23NewFoodshot%20OR%20%23최찬희_요정은_밥심이다%20OR%20%23지창민_도토리대신%20OR%20%23지창민_떡볶이말고_이건_어때%20OR%20%23뱀맛집%20OR%20%23배무맛집%20OR%20%23퉤이스티로드%20OR%20%23왕잭슨_여기_왕맛있다%20OR%20%23냠긔탱긔%20OR%20%23세훈아_이거봐라_맛있겠지%20OR%20%23드셔보세훈%20OR%20%23세훈이_세입먹을때_세프는_세그릇째%20OR%20%23세훈아_순댓국_말고_이거%20OR%20%23소원아여기가거기야%20OR\xa0%23맛린집%20OR\xa0%23은하에게_강추%20OR\xa0%23유주라잌썸띵투잍%20OR\xa0%23맛이신비해%20OR\xa0%23무지야여기무지맛있어%20OR%20%23여기먹어볼새롬%20OR%20%23문익아_여기서_파는거야%20OR%20%23먹잘알_종형아_이거_먹잘%20OR%20%23기석이_밥_먹을_시간%20OR%20%23재찬아_밥먹자%20OR%20%23먹어보시갱%20OR%20%23꼬르륵소리%20OR%20%23배부르다현%20OR%20%23상아야_여기_맛집_맞지', '%23원상아_여기_알라빙빙%20OR%20%23셔누_넌이미먹었겠지만또먹어야겠지%20OR%20%23민혁_너는이미북마크해놨겠지%20OR%20%23기현_너는맘마먹고다시시작하겠지%20OR%20%23채형원_너는세입도못먹겠지%20OR%20%23주헌_너는한입가득못먹겠지%20OR%20%23임창균_너는한끼뚝닭먹겠지%20OR%20%23웅이가_맛보면_좋겠웅%20OR%20%23우진아_맛집_추천_별거아냐%20OR%20%23동현이를_위한_대동맛지도%20OR%20%23대휘가_먹으면_아맛나%20OR%20%23지젤아밥무라%20OR%20%23윈터의_맛집을_입력해주세요%20OR%20%23닝닝이랑같이먹고싶은거%20OR%20%23지구에서여기가젤루맛있어%20OR%20%23이맛집은신이에요%20OR%20%23우리배는_식도로만_가%20OR%20%23에이티즈_우리배는_식도로만_가%20OR%20%23이게바로_에이티즈의_맛인기라%20OR%20%23이타다끼_마쓰%20OR%20%23박성화_세입컷챌린지%20OR%20%23왕맛있슨%20OR%20%23대열아_여기가맛있대열%20OR%20%23와이_렇게맛있을수가%20OR%20%23장준아나중에밥이나한끼하자%20OR%20%23태그야_맛집해시태그야%20OR%20%23승민아_여기_z지존킬z%20OR%20%23봉재현_이건_먹겠지%20OR%20%23지범_맛집다녀오겠습니다%20OR%20%23주찬아_쫓겨나기전까지만먹자%20OR%20%23주찬_넌이미여기서쫓겨났겠지%20OR%20%23동동맛집센터%20OR%20%23보민아_여기가극락인가봄%20OR%20%23Y가_최고로_모시는_맛집%20OR%20%23캐럿들_여기_캐맛있어%20OR%20%23세운아_먹어보세운%20OR%20%23이맛이꾸민지생시인지\xa0OR\xa0%23맛집으로달려라하니\xa0OR\xa0%23단다니챙겨먹자\xa0OR\xa0%23난맛집을찾는_베이비\xa0OR\xa0%23혜인아_다음에꼭같이가자%20OR%20%23손영재_콧구멍_커지겠지%20OR%20%23주현아맛있겠찌%20OR%20%23슬슐랭가이드%20OR%20%23오늘은웬디여기%20OR%20%23수영아아줌마들잘먹지%20OR%20%23누가_날_맛집으로_땡긴다악%20OR%20%23연히의_냠냐미%20OR%20%23여기수윤이자린데오', '%23NJ맛집_맞지%20OR%20%23드댕이도_드냠드냠%20OR%20%23협아_이_디저트꼭먹어봐%20OR%20%23윤성아_혼자_먹기_아까워%20OR%20%23주창욱_넌_안먹어봤겠지%20OR%20%23동윤아_맛집은_안중요한가%20OR%20%23민서가_쏠테니_많이먹어%20OR%20%23집중집중_준호_맘마타임%20OR%20%23준호야_맛있는_거_먹으러_가차%20OR%20%23이_거맛있어_협%20OR%20%23렉스에게_가장_잘맞는_맛집은%20OR%20%23영현 ...

# %%
def crawling():
    login(id, pwd, url1)
    
    for location in locations:
        tweets = []
        
        for hashtag in hashtags1:
            url = "https://twitter.com/search?q={0}%20{1}&src=typed_query&f=live".format(location, hashtag)   # 지역명과 해시태그셋 url에 넘겨주기
            driver.get(url)
            time.sleep(random.uniform(3, 7))
            
            before_location = driver.execute_script("return window.pageYOffset")
    
            while True:
    
                driver.execute_script("window.scrollTo(0,{})".format(before_location + 2000))
                time.sleep(random.uniform(3, 7))
    
                after_location = driver.execute_script("return window.pageYOffset")
                
                if before_location == after_location:     # 스크롤이 끝까지 내려갔을 경우 중단
                    break
                        
                else:
                    html_content = driver.page_source
                    soup = BeautifulSoup(html_content, 'html.parser')
                    posts = soup.find_all(attrs={"data-testid": "tweetText"})
                
                    for post in posts:
                        if post.text not in tweets:     # 중복 트윗이 아닌 경우 tweets 리스트에 추가
                            tweets.append(post.text)
                            print(post.text)
                            print("-" * 50)
                        else:
                            pass
                            
                    before_location = driver.execute_script("return window.pageYOffset")
                
        df = pd.DataFrame(tweets, columns=['tweet'])
        df.to_csv("twitter_{0}.csv".format(location), index=False)     # 지역별 csv 파일 저장

# %% [markdown]
# ### 크롤링 실행

# %%
if __name__ == "__main__":
    crawling()
# Out:
# 몽블랑솜 익선동카페
#
# #런쥔이_밥무거쒀
# #박지성_단1g도안줌
# #먹다가_해찬이_생각이나신거예요
# #재혀니_맛있게머겅
# #금동아_이거먹고_세계정복
# #아민아자주먹어
# --------------------------------------------------
# 익선동 달랭이
#
# 소곱창전골&뭉티기 히히 마싯더
#
# #태래비전출연맛집
# #조슈아_먹어보슈아
# #현이도_먹어봐
# --------------------------------------------------
# 익선동 식물
#
# 크로플 조오오오온맛
# 빠순이와 야빠를 동시에 해냅니다..
#
# #ㄷㅂㅇㅈ
# #김선우_맛있는걸내가놔둘리가
# #이게_내_마지막_밥이라고
# --------------------------------------------------
# 익선동 우연화
#
# 수제 떡갈비 맛집 !
# 숯불에서 바로 구워주고 소스도 5가지여서
# 먹는 재미가 있었어요 추천
# (마지막에 먹는 누룽지가 짱 ...)
#
# #ㄷㅂㅇㅈ
# #더보이즈_배고플땐언제든찾아와요
# #김선우_맛있는걸내가놔둘리가
# --------------------------------------------------
# 종로찌게마을
# 맛있고 양도 많아
# 웨이팅도 익선동 구경하면 금방 가서 즐거움
# 소주 홀딱 삐리빠리뽀
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 자연도가 소금빵
#
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
#  종로 티퍼런스 서울
#
# 익선동에 단체석 있는 카페 많지 않은데
# 여기 시즈니들끼리 와도 너무 좋을 것 같음
# 커피도 맛있고 티 종류도 많고 향도 너무 좋음
# 케이크도 맛있음 강추
#
# #먹다가_해찬이_생각이_나신거예요
# #런쥔이_밥무거쒀
# --------------------------------------------------
# 익선동 < 소하염전 >
#
# 매장이 예쁘길래 또 옴
#
# 바질토마토소금빵이랑 우유크림소금빵 시켰는데 미친놈처럼 먹음 개맛있음
#
# 소금크림라떼는 커피도 되게 진짜 맛있는데
# 컵에 묻혀진 소금이 진짜 개~맛잇음 꼭 먹어보시길
#
# #승연아_우즈야_여기야
# #제노의_맛그당어
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 < 소하염전 >
#
# 소금빵 에프에 살짝 구워서 먹으니까 너무 바삭하고 맛있었음 버터동굴도 되게 큰 편 간도 잘 맞음
#
# 옥수수소금빵은 그냥그럼
#
# #승연아_우즈야_여기야
# #제노의_맛그당어
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 쭈꾸미
#
# 불지옥 쭈삼 먹었는데 엽떡보다 맵다는데 난 생각보다 덜 매워서 추가로 소스 더 달라해서 거기에 찍어먹음(남들보다 매운 거 잘 먹음 나만 찍어먹었음 잘 생각해보고 더 달라해야함)
# 토마토치즈퐁듀도 존맛
#
# #모랑또놀앙
# #ㄷㅂㅇㅈ
# #주학년_푸드플렉스
# #주학년_먹는데돈아끼지말자
# --------------------------------------------------
# 익선동 카페 오얏꽃
#
# 자몽빙수와 아인슈페너 맛집
# #ㄷㅂㅇㅈ
# #지창민_도토리대신
# #지창민_떡볶이말고_이건_어때
# --------------------------------------------------
# 익선동 온천집
#
# 웨이팅 뮤서워서 항상 패스 했던 곳인데 평일 저녁이라 그런지 생각보다 널널했음 ! 얼큰육수는 커리+마라맛 쏘쏘했는데 분위기가 좋음
#
# 아 모둠튀김도 맛있음!!!
#
# #제노의_맛그당어
# #마크한테만공개
# --------------------------------------------------
# 익선동 하구
# 치즈감자전
# 마라크림바지락술찜 파스타면 추가
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 익선주택
# 홍콩와플 플레인
# 홍차크림 라떼
# 오리지널 크림 라떼
# 아이스 라떼
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 잘빠진 메밀 익선동
# 만두전골 한상
# 잘빠진 술상
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# #정한아_마니머거여ㅎㅎ
# 익선동 익선애뜻
# 한옥느낌 가게에 음식도 빨리나오는 맛집
# 비빔밥이 고소하고 맛있음..! 쌈밥은 비주얼 최고고 비빔면은 쫄깃
#
# 익선동 청수당
# 사진스팟 최고!! 부드러운 말차크림우유 추천>< 사람없는 구석 4인석에 앉아서 조용하고 편했음! 웨이팅은 좀 있는편
# --------------------------------------------------
# 종로 익선동 익선주택
#
# 홍콩와플 쫀득 달달 말랑♡ 아이스크림 아니고 젤라또인것도 좋았당♡
#
# #상호_밥_무라
# #박병찬의_밥반찬
# #최종수_오른쪽으로가다가멈춰서젓가락질_막아봐
# #원우야_여기_테이스티
# --------------------------------------------------
# #ㄷㅂㅇㅈ
# #newfoodshot
# #몬베베가_몬베베에게_추천하는_맛집
#  익선동 롤인익선
#
# 운이 좋았는지 웨이팅 하나도 안 하고 바로 들어감! 다 먹고 나왔을 때는 앞에 사람 많았더요 사실 아보카도를  안 좋아해서 그거 빼고는 다 너무 맛있었어요 가라아게동..연어초밥..후토마끼..우삼겹우동.. 최고
# --------------------------------------------------
# #승연아_우즈야_여기야
# #우즈야_무즈는_이거먹어
#  익선동 한옥랑솜
#
#  저 딸기 티라미수 아주 .. 도른자임 .. 크림 맛있고 빵은 아주 쵹.쵹.해요..  배불러서 디저트 하나만 먹었지만 다음엔 그냥 티라미수.. 딸케.. 등등 마구 먹어주마 . . 음료 특히 에이드도 영롱하도다 ..(안마셧지만))
# --------------------------------------------------
# 제또이가 맛있고 음식들이 귀여워요 (.-◡-)
#
# 익선동 치앙마이방콕
#
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 익선주택
#
# 와플 디따큼!!!
# 딸기라떼 넘 맛있답니다
# #먹다가_해찬이_생각이나신거예요
# #제노의_맛그당어
# #박지성_단1g도_안줌
# --------------------------------------------------
# 익선동 간판없는 가게
#
# 큰 기대 안했는데 넘엄넘 맛있었던..
# 스테이크 리조또 꼭꼭꼭 먹어야만!!!!!!!!!!
#
# #먹다가_해찬이_생각이_나신거예요
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 청수당
#
# 카페가 맛있고 디저트가 귀여워요
# 딸기 수플레 넘 맛있었어요..
# 가게도 한옥 느낌 가득이라 넘 쭈았던..!!
#
# #믿고먹어boo세요
# #캐럿들_여기_캐맛있어
# --------------------------------------------------
# 닭매운탕진짜맛잇엇음...평일낮에가서 웨이팅없이먹었음
# 종로3가 익선동 오죽이네
# #제노의_맛그당어
# #천러야_이거_먹기좋아
# #먹다가_해찬이_생각이나신거예요
# --------------------------------------------------
# #제노의_맛그당어
# 익선동 배수사
#
# 안주 다 존맛 … 머글친구들 착한점 제노 포카 들어줌 ♡
# --------------------------------------------------
# 익선동 온천집
# 사진을 뭐 이지랄로페테쿠스로 찍었나 싶겠지만 . ….. 포카도 까먹었지만 . .. 웨이팅 2시간이나 했지만 . ……….. 마딛다 .!.!.!.!.!.!!!!!!
# #황제님을위한메뉴판
# --------------------------------------------------
# 익선동 하루
#
# 감자전이랑 유차주 진짜 맛있어
# #ㄷㅂㅇㅈ
# #영훈아_빵빵하게_먹어
# #주연앟_맛있겠짛
# --------------------------------------------------
# 익선동 르블란서
# 익선동 오얏꽃
#
# #NewFoodshot
# #그거먹고_배가찬희
# #최찬희_요정은_밥심이다
# #더보이즈_배고플땐언제든찾아와요
# #ㄷㅂㅇㅈ
# #채형원_너는세입도못먹겠지
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 - 플리퍼스
#
# 왜 사람들이 여기서 수플레 팬케이크 테이크아웃해가는지 알겠다 … 구름을 먹는거같음
# 참고로 여기 4인용 자리는 별로 없고 웨이팅해야해요 그치만 팬케이크 가격이 2만원이고 양 많아서 4인이 가는게 합리적이긴함ㅜㅜ
#
# #박지성_단1g도안줌
# #튼튼하게_먹지성
# --------------------------------------------------
# #NewFoodshot
# #그거먹고_배가찬희
# #최찬희_요정은_밥심이다
# #ㄷㅂㅇㅈ
# 익선동 하이웨스트
# --------------------------------------------------
# 익선동 르블란서
# 양식맛집.. 새우 빠피요트, 감자그라탕, 항정살 스테이크, 갈비살 라구 파스타 이렇게 4가지를 주문했고 홍합은 많이 짰지만 나머진 맛있게 잘먹었당ㅎㅎ 스테이크 겉바속촉 대박임.. 사진은 없지만 식사하기 전에 빵도 준다!!
#
# #정한아_마니머거여ㅎㅎ
# #원우야_여기_테이스티
# --------------------------------------------------
# 익선동 세컨디포레스트
# 들깨크림파스타
# 오이스터치킨쉬림프리조또
# 스테이크샐러드룽기피자
# 맛있게 먹고 왔어여◠‿◠✿
# #뇨랑정말똘망
# #조슈아_먹어보슈아
# #후회되지만후회안돼왜냐면난행복하거든지금
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# 익선동 카페 식물
# 원래 종로에서 가려던 곳 귀찮아져서 친구랑 걍 암때나 들어간 카페였는데 최고의 선택이 됨
# 크로플? 존맛탱
# 밀크티? 대만족
# 고양이? 졸귀탱
# 이름은 오동이 라고 함 개냥이셔요
# --------------------------------------------------
# 익선동 도모다찌라멘 #ㄷㅂㅇㅈ
#
# 작년에도 추천했던 최애 라멘집 !!
# #현재도먹어 #이재현_치킨이다가아니야
# #영훈아_빵빵하게_먹어 #지창민_도토리대신
# --------------------------------------------------
# 익선동 식물
# 나의 락스타와 데이트
# #정한아_마니머거여ㅎㅎ
# #조슈아_먹어보슈아
# --------------------------------------------------
# 익선동 살롱순라
# 제노랑 천러가 플레이서울에서 갔던 식당 .◜◡◝
# 애들이 시켰던 메뉴 그대로 시켰는데 피자는 조금 매웠어요
# 그래도 다 맛있움!!
# 젠프체고  @diedie_dice
#
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 식물
#
# 분위기 좋은 카페에서 아가들이 우리 음식 뺏어먹을 작당모의 펼친동안 우린 4시간동안 더보이즈 이야기만 함
# 주제만 약 126번 바뀌면서 불나게 이야기했당!
# 근데 소년(BOY) 있는거 보고 심장 뛰었는데 술이었음..
#
# #ㄷㅂㅇㅈ
# --------------------------------------------------
# 익선동 - 롤인익선
#
# 연어롤이 유명해서 가본 맛집
# 매장이 굉장히 협소해서 2인 이상 방문하면 높은 확률로 웨이팅 해야 되니 2인 방문 추천.
#
# 연어아보카도롤이 맛있습니다
#
# #조슈아_먹어보슈아
# #THE_ATE
# #캐럿들여기캐맛있어
# --------------------------------------------------
# 익선동 - 카페 우즈베이커리
#
# 아메리카노 인심이 후함
# 에그타르트가 맛있었음
# 루프탑이 있어서 좋아요
#
# #조슈아_먹어보슈아
# #THE_ATE
# #캐럿들여기캐맛있어
# --------------------------------------------------
# 익선동 냉삼집 미미네
#
# 구워먹는 치즈랑 고기랑 같이 구워먹으면 존맛입니다
# 들기름파스타도 존맛
# 차돌박이도 꽃모양으로 나와서 사진 꼭 찍어줘야 함
# 다 먹고 마시멜로 구워먹을 수 있음!!!
#
# #먹다가_해찬이_생각이나신거예요
# #재혀니_맛있게머겅
# #제노의_맛그당어
# --------------------------------------------------
#  익선 잘빠진 메밀
#
# 평생지기랑 익선동 나들이
# #택운이를_위한_뮤술랭가이드
# #그뮤즈에_그뮤즈
# #믿고먹어boo세요
# --------------------------------------------------
# 익선동 카페 하이웨스트
#
# 승관이 닮은 곰돌이 잡아먹으러 옴
# 웨이팅은 따로 관리 안해서 빈자리나면 잽싸게 앉아야함
#
# #믿고먹어boo세요
# #캐럿들_여기_캐맛있어
# --------------------------------------------------
# 익선동 국수찾아닭만리
# 매콤짜글이통닭에 꼬옥 콘치즈 추가해서 먹어야함..
# 완전 맛있어요…
#
# #박지성_단1g도안줌
# --------------------------------------------------
# 익선동 익선주택
# 꼭 말차로 시키세요!!!
#
#  #박지성_단1g도안줌
# --------------------------------------------------
# 플롭피자
#
# 제가 간 곳은 불광천 지점이었는데 이게 연남이랑 익선동 쪽에도 있어서 가까운 곳 방문해서 드시면 돼요! 흔치않은 메뉴의 피자들이라 배부르고 너무 맛있었어요 진쯯... 베이컨이랑 닭갈비 꼭 드셔보세요
# #ㄷㅂㅇㅈ
# #어이어이_이재현_여기다
# #맛있겠짛_주연앟
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
#  익선동 라미스콘
# 창균아 너가 좋아하는 초코 수플레 케이크인데 노밀가루에 노버터인데 단백질 함량 높대 한 번 와봐
# --------------------------------------------------
#  익선동 아삐뽀레
#
# 젤라또+크로플 요 세트메뉴 진짜 짱
# 수박이랑 바닐라 젤라또가 Good...
# 넓고 편안한 분위기가 진짜 좋았어요
#
# #마크한테만_공개
# #먹다가_해찬이_생각이_나신거예요
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 맛집 #술라
# 여기 분위기 징짜 좋고 뷰가 익선동 한옥거리 뷰라서 더더 좋아요오..♡
# 포카 두고와서 같이 못 찍어서 아쉽지만 그래두우!!!!
# 개인적으로 얼그레이하이볼 보단 피치크러쉬가 존맛탱...
# #몬베베가_몬베베에게_추천하는_맛집
# #채형원_너는세입도못먹겠지
# --------------------------------------------------
#  플리퍼스 익선점
#
# 익선동 가면 꼭 들려야 하는 수플레 맛집
# 개인적으론 플레인이 제일 맛있는 듯!!
#
# #먹다가_해찬이_생각이나신거예요
# #제노의_맛그당어
# #잠깐만젠동러맛집데려가도돼
# #먹을때귀여워_웅
# #젠동러가많이팡해졌더라구요
# --------------------------------------------------
# 익선동 익선애뜻
#
# 익선동 가실 일 있다면 꼭 추천합니다 ♡
# 특히 차돌박이 부추 칼비빔면 / 치즈김치전 << 이거는 무좍건 !!!
# 자극적이지 않고 깔끔하게 한 끼 먹고와뜌요
#
# #조슈아_먹어보슈아
# --------------------------------------------------
# 익선동 - 끼룩하우스
# 너무 인스타감성 카페라서 맛은 과연..? 싶었는데 일단 마들렌 무조건 시켜야하고 쿠키도 무조건 시켜야함 애플스트러들도 맛있긴 했는데 진정한 메뉴는 마들렌이었다 폭신폭신행... 그리고 익선동의 풍경을 볼 수 있는 넓은 통창 최고
# #박지성_단1g도안줌
# #튼튼하게_먹지성
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# #셔누_넌이미먹었겠지만또먹어야겠지
# #민혁_너는이미북마크해놨겠지
# #기현_너는맘마먹고다시시작하겠지
# #채형원_너는세입도못먹겠지
# #주헌_너는한입가득못먹겠지
# #임창균_너는한끼뚝닭먹겠지
# 익선동 배키욘방!! 좀 가격이 치솟았지만 꽤 맛있었음!
# --------------------------------------------------
# 익선동 온
#
# 가마솥 카스테라랑 얼그레이 푸딩 진짜 개존맛이니까 꼭 먹어보세여  콘서트 영상 다시 정주행하고 고척까지 찍고온 하루
# #민규라고치고_디너쇼해도돼
# #도겸이도_도아할_맛집
# --------------------------------------------------
# 밀토스트 익선동
#
# 1일 1빵
# #민규라고치고_디너쇼해도돼
# #우지를삼킬순없잖아
# --------------------------------------------------
# 종로3가 인사동 익선동 백스트리트피자
#
# 나사진진짜개못찍는다어떡함?.... 여튼 쉬림프 갱스터가 진짜 미친놈임 나 이러케 새우 마니 올려주는 피자집 첨봄! 쫌 매콤해여 쿼터스트릿도 다 맛 ㄱㅊㄱㅊ 맥주도 쫌 있어서 피맥하기 좋음
# #조슈아_먹어보슈아
# --------------------------------------------------
# 익선동 롤인익선♡
# 모두 맛점~..♡♡♡
# #정한아_마니머거여ㅎㅎ
# --------------------------------------------------
# #승철이_이거먹고_볼빵빵했꾸마
# 익선동- 낙원역
# --------------------------------------------------
# #승철이_이거먹고_볼빵빵했꾸마
#  익선동- 솔솥
# --------------------------------------------------
# 백현아 익선동 가면 익선애뜻 요기 한번 가보세요  특히 차돌박이 부추 칼비빔면이랑 옥수수 치즈 김치전은 울백현이가 너무 좋아할 맛
# #백현이를_위한_맛집투어
# --------------------------------------------------
# 익선동 온천집
#
# 웨이팅한시간해서 들어갔다 ..사람짱많아
# 된장샤브랑 얼큰샤브랑 고민하다가 된장먹었는데 맛있었음 ~!~!!!
# 샤브샤브맛집 인정♡!!
# 직원분이 엄청친절하게 알려주시고
# 안쪽에는 1,2사진처럼 온천느낌나는 정원으로 되어있다 !!
#
# #ㄷㅂㅇㅈ
# #맛있겠짛_주연앟
# #이주연_난늘배고파_베베
# --------------------------------------------------
# #ㅈㅅㅇㅇㅈ
# #승연아_우즈야_여기야
# 익선동 리치몬드 딤섬
# --------------------------------------------------
# 익선동 익선애뜻
# 차돌박이 부추 칼비빔면
# 돼지고기 강된장 쌈밥
# 맛 괜찮았음~~
# #강민탐방 #kcal_플랙스
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 창화당
#
# 먹느라 정신없어서 사진은 없지만 창화당 김치말이국수 꼭꼭 드세요... 쫄탱한 면이랑 김치랑 환상의 탭댄스를 경험할 수 이씀
# #런쥔이의_맛집내비게이션
# #손영재_콧구멍커지겠지
# #백현아_먹짱일기_적짱
# --------------------------------------------------
# 익선동 익선주택
#
# 말차 크림 와플 지대 맛남 아이스크림이랑 시럽이랑 번갈아서 곁들여 먹으면 그냥 천국... 음료도 무난하고 맛있어요!! 익선동 가면 꼭꼭 가봤으면 함...
# #런쥔이의_맛집내비게이션
# #먹다가_해찬이_생각이_나신거예요
# #손영재_콧구멍커지겠지
# #백현아_먹짱일기_적짱
# --------------------------------------------------
# 익선동 하이웨이스트
#
# 너무너무귀여운 토끼 케이크 보고 갔는데 매장 자체가 빈티지하고 예쁜 빵 천국이었던...
# #런쥔이의_맛집내비게이션
# #먹다가_해찬이_생각이_나신거예요
# #손영재_콧구멍커지겠지
# #백현아_먹짱일기_적짱
# --------------------------------------------------
# ო̤̮ 익선동 끼룩하우스
#
# 모든 디저트가 맛있음! 커피랑 환상적으로 잘어울림 또 와야쓰것으
#
# #정한아_마니머거여ㅎㅎ
# #어이어이_이재현_여기다
# --------------------------------------------------
# #승연아_우즈야_여기야
# 익선동 호호식당
#
# 우니 오일 파스타가 진짜 미쳤어요,, 우니 좋아하시는분들은 꼭 드셔보시길 ! ! 우니 녹진하고 고소해욕!!! 세명이서 네개시켰는데 맛있어서 다먹었던..  ◠‿◠ 시킨 메뉴 다 맛있었어요!
# --------------------------------------------------
# 익선동 온화
#
# #순영아_이거_맛있어
# #캐럿들_여기_캐맛있어
# --------------------------------------------------
# 익선동 빠리가옥
#
# 까르보나라에 달걀 노른자 섞어서 호록
# 살치살 스테이크 한 입 후 맥주 한모금 하면 이만큼 맛있는게 없어요
# #제노의_맛그당어
# #나나나나_원필이가_먹을래
# --------------------------------------------------
#  익선동 온천집
#
# 줄서는식당 나온 샤브샤브집!!! 웨이팅 각오했는데 30분만에 입장 2번 이름부르고 없으면 넘어가버리니까 앞에서 대기는 필수 깜박하고 포카 챙겨갔는데 냅다 찍어버리고 냠냠 먹었어여.. 미나리육전 필수.
#
# #민규라고치고_디너쇼해도돼
# #밍구야_식샤합시다
# --------------------------------------------------
# 익선동  : 익선디미방
#
# 런치 2인 세트로 배부르게 먹음
# 샐러드 맛집이야 샐러드가 너무 맛있었어
# 그냥 전체적으로 먹을만했구
# 야채플레이트에 있는 옥수수는 별루 ..
# #순영아_이거_맛있어
# #캐럿들_여거_캐맛있어
# --------------------------------------------------
# 익선동 보보
# 어딜가도 사람 복작복작한 익선동이지만
# 여긴웨이팅도 없고 가게도 너무 이쁘고 친절했어요~
# 저희는 운좋게 텐트자리에 앉아서 먹었어요
# 갬성 짱
# 그리고 무엇보다 저 감베리 오일파스타가 너무너무너무 맛있음...
# #ㄷㅂㅇㅈ #맛있겠짛_주연앟 #이주연_난늘배고파_베베
# --------------------------------------------------
# #제노의_맛그당어
# 익선동 온천집
#
#
# --------------------------------------------------
# 익선동 익선문구사
#
# 실물파^^! 맛있었다^^!
# #허나아_밥먹자
# #조슈아_먹어보슈아
# --------------------------------------------------
# 익선동 해피치즈스마일
#
# 로제떡볶이 위에 감자튀김 대신 당면튀김 올려서 먹었는데 다음에는 감자튀김으로도 먹어보고 싶당
# #도겸이도_도아할_맛집
# --------------------------------------------------
# 익선동-익선주택
#
# 와플이 왕 크고 맛있어요 생각보다 커서 당..황.. 했지만 다 먹음 커피는 평범! 옆자리에서 먹는 차가 쫌 부러웠음.. 예쁜 투명 주전자에 주더라구요.. 담에 간다면 차를 먹어보겟슴
#
# #백현이를_위한_맛집투어
# #경수야_여기가_맛집이디오
# #문대야_피미야_여기야
# --------------------------------------------------
# #원우야_여기_테이스티
# 익선동 백스트리트피자
#
# 직원이개싸가지없엇는데도인정한맛집
# 걍저를믿고새우한판드세요
# 글고가게가존나어두움
# --------------------------------------------------
# 아니진짜..개마싯다미친
# --------------------------------------------------
# 익선동 온천집
# 청수당
#
# 된장샤브샤부 마싯엇다,,, 스테이크 덮밥은 밥만 맛있음 ㅎㅎ
# 바로 앞이 청수당이어서 밥먹구 바로 가기 좋고 인테리어 준나 예쁨 ♡!! 사진찍기 좋구 수플레가 진짜 개맛있다~~
# #제노의_맛그당어
# #이재현_치킨이_다가아니야
# --------------------------------------------------
#  익선동 낙원역
#
# 별로야 가지마 사진 찍긴 좋아 근데 사람 너무 많아  다른 넓고 예쁜곳 가
#
# #천러야_이거_먹기좋아
# #제노의_맛그당어
# --------------------------------------------------
#  익선동 살라댕방콕
#
# 사실대로 말할까? 굳이 싶었음 식당이 예쁘긴 정말 예쁜데 맛은 굳...이? 여기서? 이 돈 주고? 난 모르겠다
#
# #천러야_이거_먹기좋아
# #덕준아_이세상엔_맛있는게많다
# #제노의_맛그당어
# #이거맛있쿤
# --------------------------------------------------
#  종로 황산샤브샤브
#
# 종각역 2출에서 가깝고 인사동이나 익선동 가기 전에 가도 괜찮지 않을까 하네요.. 내가 먹어본 훠궈중에 젤 맛있음 .. 그때 그맛을 그리워하며 오늘은 본점에 다녀왔어용
# 이제는 콘이와 나우를 믿고 가줄 때가 됐다
#
# #나나의_맛집탐방기
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 온천집 / 도넛정수
# 온천집 모듬튀김 꼭 시켜먹기𖤐
# 도넛정수 인테리어 깔끔 도넛종류도 꽤 다양함!
# #백현아_먹짱일기_적짱
# #백현이를_위한_맛집투어
# --------------------------------------------------
#  익선동 온천집
#  익선동 도넛정수
#
# 몬베베도 아니고 캐럿도 아닌데 맛집 추천하려고 해시 빌립니다!! 온천집 가실 때는 꼭 고기추가 하세요!! 도넛정수는 가게 시그니처가 호랑이라 호시한테도 추천…
# #순영아_이거_맛있어
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 대전 온천집
# 익선동 온천집 분점이에요 사실 기대 엄청하고 갔는데… 그냥 그래요 된장샤브 먹었고 맛이 없진 않았는데 그 가격 주고 먹을 맛이 아닌듯… 우삼겹이 맛없을리가 x 된장국물에서 살짝 비린 맛 나고 물도 비린맛 나서 환장하는 줄 알았어요
# #나나의_맛집탐방기
# #제노의_맛그당어
# --------------------------------------------------
# 따수운 겨울..
# 감성빠순계가 하고 싶다면..
# 익선동 뜰안 추천
# #원우야_여기_테이스티
# #우지를삼킬순없잖아
# --------------------------------------------------
# 익선동 라미스콘
#
# 글루텐프리 스콘집이래요! 여기 생크림 맛있음!!
# #도겸이도_도아할_맛집
# --------------------------------------------------
# 익선동 롤인익선
#
# 아보카도연어롤 하나도 안 느끼하고 맛있어여! 그리고 여기 생맥이 1시부터 4시까지 이천원으로 할인함!! 굳굳
# #도겸이도_도아할_맛집
# --------------------------------------------------
# ◌ 익선동
# 롤인익선 / 카페하이웨스트
# 평일이라 웨이팅 하나도 없고 넘 맛있어서 좋았어야 사진에는 없지만 롤인익선에서 연어롤 꼭 먹어주기 ! 카페 분위기도 너무너무 좋앗서요 유럽온것 같았음
# #원우야_여기_테이스티
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# #승연아_우즈야_여기야
# 익선동 롤인익선 / 익선주택
#
# 연어초밥 연어아보카도롤 치킨가라아게 꼭먹어줘야함 아보카도롤은 한입에 넣으면 입터질정도였음 배도 충분히 차고 연어도 너무 부드러웠다 가라아게도 맛집임 그리고 익선주택 메뉴 대체로 다 크기가 커서 놀랐음 홍콩식와플 완전 맛있다.. ♡
# --------------------------------------------------
# #도겸이도_도아할_맛집
# 익선동 끼룩하우스
#
# 토마토 바질 에이드 너무 맛있다..
# 디저트류도 쏘쏘
# 근데 자리가 편한 편은 아님!
# --------------------------------------------------
# #도겸아_여기야_피자대동여지도
# #도겸이도_도아할_맛집
#  익선동 백스트리트피자
#
# 한 조각 한 조각이 천국이네요.. 신이 내려주신 선물이네요.. 도우가 얇아서 너무 좋구.. 새우가!! 진짜 통통하고 매콤하고 너무 맛있고.. 감튀도.. 페퍼로니도.. 치즈패티두.. (이거치즈버거맛남)  푸파하고 옴
# --------------------------------------------------
# 크리스마스 분위기 최고의 곳! 산타가 여기 온 것 같아ㅠ 여기 가면 트러플 뇨끼 꼭 먹어야 해..!
# 익선동 기러기둥지
# #ㄷㅂㅇㅈ #김선우_맛있는걸내가놔둘리가
# --------------------------------------------------
# #먹어봤도영
# #우와_저맛집유맹해
# #도영이의유맹맛집
# #백현이를_위한_맛집투어
# 익선동 돈부리파스타
#
# 줄 서서 먹는 맛집 맞네 맛있네 ₍₍ ᕕ( ᐛ )ᕗ⁾⁾.ᐟ.ᐟ.ᐟ
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# 익선동 121! 여기 카레 간 적당하고 퓨전 한식이라 청국장 비빔밥도 팔고 연탄돈까스라고 메인으로  밀고 있는 것도 맛있어요! 하지만 사진은 반반카레밖에 없는...
# --------------------------------------------------
#  익선동 온천집
#
# 요즘 같이 추운 날 먹기 딱 좋아요 !
# 된장 샤브가 진짜 맛있고 첫 주문에 5000원만 추가하면 고기 한 판 더 줍니당 ◡̎
# 웨이팅이 긴 편이라 미리 예약하고 가시는 게 좋을 것 같아요 (당일 예약은 안 됨)
#
# #승연아_우즈야_여기야
# --------------------------------------------------
# 익선동 백스트리트 피자
#
# 종로에 있는 건데 짱 맛 해프엔해프로 쉬림프랑 포테이토 먹었는데 달달하구 맛있다 무엇보다 브레이크 타임도 없고 웨이팅도 없어서 좋았어요 굿
# #도겸이도_도아할_맛집
# #어이어이_이재현_여기다
# #이주연_난늘배고파_베베
# --------------------------------------------------
#  익선동 낙원역
# 청수당 느낌 나구 예뻐용 디저트가 회전초밥처럼 전시되어 있어서 신기했음 맛은 쏘쏘 .. 분위기 좋은 카페 찾으신다면 추천합리노
#
# #리노는_배고파
# #현이도_먹어봐
# #아기빵_크림채워
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 디디피 광탈 기념으로 덕투~
# 익선동 살롱순라 !!
# 명란크림파스타 대대대대존맛
# 근데 양이 많네요,, 거의 1인분 남김..
# @nAnyong_z @Ae_jungdld
# #제노의_맛그당어
# #마크한테만공개
# #먹다가_해찬이_생각이나신거에요
# #성찬이의_진수성찬
# #정우의_원데이식스밀
# #먹어봤도영
# --------------------------------------------------
# 백스트리트피자
#       익선주택
#
# 익선동 추천 코스 ◟( ˘ ³˘)◞ ♡
#
# #제노의_맛그당어
# #런쥔이의_맛집내비게이션
# --------------------------------------------------
# 익선동 - 잘빠진 메밀
# 오죽이네 휴무라 찾아보다 갔는데
# 원래 예상하지 못한 맛집 발견이 200퍼 행복하게 만든다고..진짜 넘 맛있어요ㅠ
# 살면서 간 메밀집 중 최고! 메밀만두 꼭 시켜요제발
# #최연준_맛집1등어디야
# #재민아_밥먹어 #나나의_맛집탐방기
# #이재현_치킨이다가아니야
# #박지성_단1g도안줌
# --------------------------------------------------
# #순영아_이거_맛있어
# #도겸이도_도아할_맛집
# 익선동 백스트리트
# 익선동 오얏꽃
#
# 쉬림프반 포테이토반 .. 피자는 배신안해
# 자몽빙수도 우유맛 찐하고 탱글탱글 맛있음
# --------------------------------------------------
# #마크한테만공개
# #제노의_맛그당어
#
# 사실 수플레 안 익은 날달걀 냅다 먹는 느낌이라 별로 안 좋아했는데 여긴 적당히 익히고 부드럽고 맛있는...!! 익선동 놀러갈 일 있음 여기 추천 ♡
#
#  플리퍼스 익선점
# --------------------------------------------------
# 익선동 온천집
#
# 오래 기다린만큼 너무 맛있었던
# 훠궈 같은 샤브샤브 좋아하면 꼭 가야할 곳
# 된장 국물이랑 얼큰이 있는데 매운 거 못 먹는 사람들도 먹을 수 있을 정도의 맵기인 것 같은
# 직원분들도 너무 친절하시고 좋아요
#
# #정한아_마니머거여ᄒᄒ
# #순영아_이거_맛있어
# --------------------------------------------------
# #제노의_맛그당어
# 익선동 살롱순라
#
# 뉴랜덤다이버 끝나구 뭐먹을까 고민하다가 여기 근처 온 김에 덕후투어 하자! 하구 찾아 온 곳!
# 피자도 맛있는데 무엇보다 명란크림파스타가 진짜 너무 맛있었어요.. 꼭 여기 가시면 이거 드시기 추천추천입니댯 .◜◡◝
# --------------------------------------------------
# 익선동 롤인익선
# #원우야_여기_테이스티
# #쫄랭아_여기_테이스티
# --------------------------------------------------
# 종로3가역 익선동 <익선주택>
#
# 와플이랑 아이스크림 조합이라니 뭘 아시는 분이 분명하시다 음료수도 맛있구 분위기가 너무 좋아서 철이랑 찬이두 한번쯤 와서 먹었음 좋겠다
#
# #승철이_이거먹고_볼빵빵했꾸마
# #디노야_여기_케이밥의_미래
# --------------------------------------------------
# 익선동 <롤인익선>
#
# 여기 롤초밥이 진짜 미친X입니다...
# 롤초밥만 하루종일 먹고싶을정도로 맛있음...
#
# 익선동 <하이웨스트 익선>
# 초코케이크 맛있습니당 찐~하고 아주 맛남
#
# #맛있겠짛_주연앟
# #이주연_난늘배고파_베베
# #ㄷㅂㅇㅈ
# --------------------------------------------------
# #조슈아_먹어보슈아
#
# 종로 익선동- 워터밀
#
# 바질리소토
# 라구소스 라자냐
# 세트 에피타이저
# (크림뇨끼 )
#
# 음식 맛은 평타이상!! 라자냐는 그냥 라자냐맛
# 리소토도 리소토맛..
# 화장실 근처 자리는 화장실 냄새가 좀 나요ㅠ
# --------------------------------------------------
# 익선동 롤인익선
#
# 가게 이름이 롤인익선인데는 이유가 있다 롤이 미친놈 꼬옥 연어롤 먹어주면 되。。。
#
#  #창균아_오늘의_일반식
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# #창균아_오늘의_일반식
#  익선동 라미스콘
# 현우야 여기 비건빵집!!
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# #창균아_오늘의_일반식
#  익선동 돈부리 파스타
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# 익선동 르블란서♡
#
# 맛녀석들에도 나온 적 있는 프랑스 가정식 집인데
# 인테리어도 예쁘고 분위기 좋아용
# 그리고 무엇보다도 진짜 맛있음!!!!!!
# 로스티드 치킨 육즙 대박이고
# 갈비살 라구 파스타 입에서 살살 녹음
# 뇨끼랑 라따뚜이도 맛있어용
# --------------------------------------------------
# 익선동 호호식당
#
# 제 인생 일본가정식집 ♡⸝⸝ 가츠나베랑 스키야키정식 시켰는데 진짜 너무 맛있었어요.. 부타가쿠니도 먹어보고 싶었는데 마감돼서ㅜ 다음에 꼬옥 먹어보는걸로... 성수 혜화 도산점도 있으니까 가까운 곳으로 가시면 될 것 같아용:)
#
# #제노의_맛그당어
# #박지성_단1g도안줌
# --------------------------------------------------
# 종로 익선동 도모다찌라멘 #ㄷㅂㅇㅈ
#
# 여기 내 최애 라멘집 !! 비주얼 미쳤음 근데 가라아게가 진짜 맛있음 ( ･ᴗ･̥̥̥ )
#
# #현재도먹어 #이재현_치킨이다가아니야
# #맛있겠짛_주연앟 #이주연_난늘배고파_베베
# --------------------------------------------------
# #박지성_단1g도안줌
# 익선동
#  롤인익선
# 사진으로 봤을 땐 몰랐는데 초밥이 디게 커요 ..  둘이 메뉴 두개 시키니까 딱 좋음 !! 나갈 때 하리보도 주신답니당
#  하이웨스트
# 뭘 먹을지 고민될 정도로 빵 종류가 많았음!! 케이크도 맛있었구 아인슈페너에 크림 대박 .. 츄릅
# --------------------------------------------------
# 익선동 하이웨스트
# 체리케이쿠가 상큼하고 맛있다 .ᐟ
#
# #ㄷㅂㅇㅈ
# #지창민_도토리대신
# --------------------------------------------------
# ➹ 경주 황리단길 온천집
#
# 샤브샤브 전문점 .ᐟ .ᐟ 훠궈 좋아하시는 분들에게 샤브샤브 북해도식 추천해요 약간 매콤하니 딱 좋음 ᵔ ᵔ 그리고 비프 스테이크 정식 짱맛 체인점이라 익선동이랑 또 다른 어딘가에도.. 있습니다앙
#
# #백현이를_위한_맛집투어
# #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 살라댕 방콕
# 가성비 태국여행 성공..
# 쏨땀은 파파야랑 당근 오독오독 쫄깃쫄깃 씹히고 새콤함!!
# 푸팟퐁커리는 게껍질 지인짜 부드럽고 맛있었슴…
# 팟타이도 소스 양 적절해서 뻑뻑하지 않고 촉촉하고 고소했음
# 생숙주랑 섞어먹으니 아삭아삭한 식감
# 하 땡모반도 마실걸 ㅠ
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 온천집
#
# 고기 추가 한 번 정도는 하시는 걸 추천! 그래야 좀 만족할 수 있는 양...❤︎ 앗차차 지나가다 보셨음 알겠지만 익선동에서 웨이팅 가장 긴 곳이라고 할 수 있는 곳 ⸝⸝ʚ̴̶̷̆ ̯ʚ̴̶̷̆⸝⸝ 잊지 말고 꼭 예약하고 가세요 •••
#
# #백현이를_위한_맛집투어
# #경수야_여기가_맛집이디오
# --------------------------------------------------
# #승연아_우즈야_여기야
# 익선동 르블란서
#
# 블루치즈홍합찜 항정살스테이크 살치살 스테이크 문어&바지락파스타
#
# 블루치즈홍합찜 소스에 찍어먹은 감자튀김과
# 항정살 스테이크 너무 맛있고 식전빵에 앙버터 바르고 프렌치 어니언 스프랑 먹으면 천국감
# 분위기 좋고 조명이 은은하게 예뻐서 셀카 명당
# --------------------------------------------------
# 익선동 <살라댕 방콕>
#
# 뿌팟퐁 커리랑 짜두짝 빠에야 먹었는데 커리는 살짝 느끼했고 빠에야가 매콤하고 맛있었어용 .◜◡◝
#
# #제노의_맛그당어
# #재민아_밥먹어
# --------------------------------------------------
# 익선동 오죽이네 / 라미스콘
# 닭매운탕에 칼국수+수제비 꼭 추가해서 드셔야해요,,,마지막 볶음밥까지 정말 안 맛있던 순간이 없는!!!! 찐추천!×913
# / 바나나초코수플레 먹었는데 비건스콘맛집으로 유명하더라구요! 수플레는 그냥 그래씀다!
# #성찬이의_진수성찬
# #제노의_맛그당어
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# 익선동 백스트리트 피자  =͟͟͞͞♡
# 너무 배부르고 분위기가 예쁘다｡｡
# --------------------------------------------------
# #승철이_이거먹고_볼빵빵했꾸마
# 익선동 백스트리트피자
#
# 감튀랑 새우올라간거 꼭 반반해먹어야함 JMT
# 양은 셋이 먹어도 배터지게 먹을양이구 분위기도 좋았음
# 코젤에 생크림추가 꼭 해먹기
# --------------------------------------------------
# #정한아_마니머거여ᄒᄒ
# #조슈아_먹어보슈아
# 익선동 <플리퍼스>
# 여기 수플레 맛집!!
# 빵도 빵이지만 크림이 달달해서 너무 맛있었어!
# --------------------------------------------------
# #박지성_단1g도안줌
# #제노의_맛그당어
#  익선동 구르미산도
#
# 미친 물가의 익선동에서 쉽게 볼 수 없는 저렴한 곳이에요 물론 맛도 있음  특히 과일청 들어간 구르미소다가 상큼하고 맛나용
# --------------------------------------------------
# 익선동 청수당
# 분위기고 짱짱이고 무엇보다 딸기 수플레 카스테라를 무조건 무조건!!! 시키세요!!!!! 진짜 당장 구속시킬 뻔한 맛!!!!!
#  #몬베베가_몬베베에게_추천하는_맛집
# --------------------------------------------------
# 익선동 롤인익선
#
# 연어드래곤롤, 연어초밥, 연어아보카도롤, 우삼겹우동 다 너무 맛있어요..
# #민규라고치고_디너쇼해도돼
# --------------------------------------------------
#  익선동 롤인익선
# 연어사랑러들은 꼭 가주기 .. ♥︎
# 아보카도롤이 생각보다 넘 맛있음
#
#  #백현이를_위한_맛집투어
# --------------------------------------------------
# #나재민_밥먹어
# #먹다가_해찬이_생각이나신거에요
# #런쥔이의_맛집내비게이션
# #천러야_이거_먹기좋아
# #박지성_단1g도안줌
# 익선동- 롤인익선 송암여관 영진수산
# 연어도 원없이 먹구...막창전골도 원없이 먹구...회도 원없이...롤인익선은 가성비가 좋고 송암여관은 분위기가 좋고 영진수산은 신선해요
# --------------------------------------------------
# #ㄷㅂㅇㅈ
# #김선우_맛있는걸내가놔둘리가
# 익선동 한그륵
# 스테이크정식 & 연어덮밥
# 연어덮밥 위에 올려진
# 다진 참치 밥위에얹어서
# 간장꼬옥찍어드셔주면되...
# 진짜 미친놈이에요♡
# --------------------------------------------------
# #ㄷㅂㅇㅈ
# #김선우_맛있는걸내가놔둘리가
# 익선동 청수당！
# 자두 청수 & 딸기 수플레 카스텔라 존.맛....
# 분위기도 짱 ฅʕ•ﻌ•ʔฅ
# --------------------------------------------------
# 어제 젠몽이와 첫 외출로 갔던 플레이서울 익선동 세느장 카페!제노 자리에서 손민수하구 사진도 찍었으요
# #제노의_맛그당어
# --------------------------------------------------
# 익선동 백스트리트 피자
#
# 네명이서 새우랑 감튀 하프앤하프 라지 시켰다가 나만 두 조각 다 먹음 (~˘▾˘)~ 그만큼 피자가 어마어마하게 크다! 레귤러로 먹으면 적당히 배부를 듯
# 그리고 급한 이즈의 호시 포카...
#
# #원우야_여기_테이스티
# #공상밥상
# --------------------------------------------------
# 익선동 라미스콘
# 여기 글루텐프리 스콘도 팔고...
# 팥스콘도 팔고...
# 호박 스콘도 팔고
# 아무튼 많은 스콘을 팔고 있는 가게...
# 그중에 내 픽은 팥스콘...
# 왜냐하면 안에 팥소가 들어있음 #ㄷㅂㅇㅈ
# --------------------------------------------------
# #ㄷㅂㅇㅈ
# #김선우_맛있는걸내가놔둘리가
# 익선동 한그륵
# 거대한 갈비 .. (메뉴이름임 진짜로)
# 맛있당
# --------------------------------------------------
# #황제님을위한메뉴판
#
# 압구정로데오 호금장 곱창전골
# 연남 봄띠
# 익선동 백스트리트피자
# 명동 마카오도우라오 훠궈
#
# 다음엔 사진 잘찍어와야지 ♡( ૢ⁼̴̤̆ ꇴ ⁼̴̤̆ ૢ)~ෆ♡
# --------------------------------------------------
# #도겸이도_도아할_맛집
# #파랑웅냥냠
# 익선동 청수당
# 여기도 유명하긴 하지만 머..
# 수플레 카스테라 첨 먹어보는데 정말 미쳤으요... 1000g은 4-5인용이래서 600g짜리 시켰는데 셋이서 5분 컷 했구.. 더 큰 걸 시킬걸 후회함... 음료도 다 맛있어용
# --------------------------------------------------
# #도겸이도_도아할_맛집
# #파랑웅냥냠
# 익선동 돈부리파스타
# 곱창청양크림파스타 JMT.. 신라면도 못 먹는 본인도 중독되는 매운맛이고 느끼함도 못 느낌 그리고 곱창이 정말 맛있는듯..
# 라구는 어제부터 신상이라던데 특별한 맛은 아니여도 맛있고 무난하니 먹기 좋음!!
# --------------------------------------------------
# 익선동 온천집 #정한아_마니머거여ᄒᄒ 날도 추운데 뜨신 샤브샤부 어떠니 정한아
# --------------------------------------------------
# #ㄷㅂㅇㅈ 오늘은 연어!!! 마싯닿>__< 익선동 롤인익선~ 쥬여니두 연어 조아하니?˙◠ ̫◠
# #맛있겠짛_주연앟
# #이주연_난늘배고파_베베
# --------------------------------------------------
# 익선동 호호식당
#
# 제노가 좋아하는 사케동!! 연어가 두툼해서 너무 맛있었어.◜◡◝
# #제노의_맛그당어
# --------------------------------------------------
# #원우야_여기_테이스티
# 이 돈까스 진짜 맛있엉 익선동에 있는데 포카를 깜빡하고 안들고갔어....
# --------------------------------------------------
# 익선동 서울커피
# 예전에 갔던 곳인데 갑자기 또 가고싶어져서.. 앙버터 맛있고 한옥 느낌?으로 카페도 예뻐서 좋음 ෆ
# #원우야_여기_테이스티
# --------------------------------------------------
# 익선동 백스트리트피자
# 진짜 진짜 맛있고 토핑이 많아서 좋았어 피자 조아하는 민혁이가 꼭 한 번 먹어봤음 좋겠엉
# #몬베베가_몬베베에게_추천하는_맛집
# #민혁_너는이미북마크해놨겠지
# --------------------------------------------------
# #정한아_마니머거여ㅎㅎ
# 익선동 돈부리파스타
# 왼쪽 매운 닭갈비 파스타가 진짜 마싰어여
# 콘안에 있는게 고구마 크림인데 꾸덕한 크림소스와 닭갈비가 함께있어서 느끼하지도 않구 진짜 짱짱 웨이팅이 길긴하지만 기다릴수있는 맛이였어여 (๑>◡<๑)
# --------------------------------------------------
# #도겸아_여기야_피자대동여지도
# #믿고먹어boo세요
# 익선동 백스트리트피자
# 새우 진짜 비속어 나오는 맛...꼭 먹어야합니다 #첼이밥_삘릿얌
# --------------------------------------------------
# #몬베베가_몬베베에게_추천하는_맛집
# 익선동 백스트리트피자! 종로3가역 바로 앞에 있음 쉬림프랑 포테이토 레귤러 시켰는데 셋이서 다 못먹고 남김.!!! 짱맛있고배부름 근데문열자마자계단나와서생각없었으면굴러떨어질뻔
# --------------------------------------------------
# 쥬프와 함께
# 익선동 돈부리파스타
# 줄서느라 넘 더웠는데
# 닭갈비파스타 한입 먹고 까먹음
# #ㄷㅂㅇㅈ
# --------------------------------------------------
# #승연아_우즈야_여기야
# 익선동 끼룩
# 승연아 여기는 3층으로 되어있는 카페인데 2층은 탁 트인 전경이 예술이고 3층은 루프탑으로 되어있어 에이드랑 빵들이 촉촉하고 바삭하니 맛있어  ◡̈
# 특히 큰 창문을 통해서 전경을 보다보면 시간가는줄 모르게 되고 고양이들 보는 재미도 있어
# --------------------------------------------------
# #황제님을위한메뉴판
# 익선동 호호식당
# 한옥 분위기 너무 좋네! 제일 유명한 메뉴는 스키야끼 정식인데 개인적으로 카이센동 추천하고 싶어요 연어랑 연어알 그리고 와사비까지 맛있어요 ㅋㅋ
# --------------------------------------------------
# #승연아_우즈야_여기야
# 익선동 익선주택
# 승연아 여기는 홍콩식 와플을 파는곳이야 0.=
# 바나나랑 누텔라랑 아이스크림이 곁들여진 와플인데 달달하니 맛있어  ◡̈
# 카페 인테리어도 분위기도 잔잔하니 승연이 너가 오면 좋아할거 같아 ◡̈ —॰˳ཻ̊♡
# --------------------------------------------------
# #강다니엘_염염긋
# 익선동 밀토스트
# 부드럽고 달콤한 블루베리 치즈케잌과 토스트 아메리카노랑 얌얌!
# --------------------------------------------------
# #백현이를_위한_맛집투어
# 익선동 이태리 총각들. 골목 깊숙한 곳에 위치한 한옥을 개조해 만든 피자 전문 식당. 시오리 피자는 루꼴라에 치즈로 튀긴 새우가 일품이야. 사람들 눈에 띄지 않고 편히 먹고 여유를 가질 수 있는 곳이니 쉬었다 가길 바라면서..
# --------------------------------------------------
# #먹어봤도영
# 익선동 온천집
# 된장샤브샤브가 맛있었다. 인테리어도 이뻤음
# --------------------------------------------------
#  오늘그대와 익선
#
# 주말의 익선동에서 웨이팅 없이 밥 먹는 법...
# 예약되는 곳을 찾는다<< 라서 갔는데 실패한 메뉴 없이 다 괜찮았다!! 버섯리조또 굿
# 근데 1인 1메뉴임.. 물론 싹싹비움 ◠.◠
#
# #지우야_맛집은여기
# --------------------------------------------------
# [서울 종로3가/익선동/탑골공원] 익선동목장
#
# 감자채 구워주는게.. 진짜 맛있움...
#
# @도브님 @벤츠님 @복됴님
#
# #재혀니_맛있게머겅 #먹어봤도영 #가지_않았나요_재앤도와_함께
# --------------------------------------------------
# 서울 종로3가 익선동 맛집 존맛 피자 파스타 쏘쏘
# 지오쿠치나익선 ♡
# #강동호_먹어봐
# --------------------------------------------------
# 익선동 카페 존맛티비 타르트 빵집 종로3가 맛집
# 낙원장
# 개추루루듑ㅂㄱ추츛츕ㄹ베흡
# 저 초코어쩌고..빵이제일개추베릅이야!!!
# #강동호_먹어봐
# --------------------------------------------------
# 익선동 121
#
# 연탄 돈가스가 신기하고 재밌음 케이크도 같이 나오는데 포켓몬 고오스 초코빵 맛나요
# 토마토 커리도 맛있으니 츄라이 해보시길 추천
#
# #크리스_배고파용
# #한이의_한입거리
# #여기맛있승민
# #리노는_배고파
# --------------------------------------------------
# 익선동 종로3가역 맛집
# 익선취향
#
# 회오리 오므라이스
# 취향 스테이크
# #강동호_먹어봐
# --------------------------------------------------
# 익선동 종로3가역 카페
# 자몽 빙수 맛집 !!
# 오얏꽃
# 개추ㅜㅜㅠㅠㅠ츄ㅠㅠㅜ베릅ㅋ
# #강동호_먹어봐
# --------------------------------------------------
#  익선동 호텔세느장
#
# 좋은 자리 앉아서 좋았음!! 커피는 안마셔서 모르는데 밀크티는 맛있었고 수플레가 달달해서 최고~! 장식이 마리앙투아네트 재질이길래 도영이 포카도 슬쩍… 마리앙 보고싶다 (??갑자기요??) 하튼 분위기 굿인 곳!
#
# #먹어봤도영
# #정우의_원데이식스밀
# #정우의_원데이씩스밀
# --------------------------------------------------
#  익선동 아담집
#
# 오코노미야끼가 짱 맛있어요  사장님 직원 분 넘넘 친절하시구 시끄럽지 않은 술집이라 좋아용
# #먹어봤도영 #정우의_원데이씩스밀
# --------------------------------------------------
# #정우의_원데이식스밀 #정우의_원데이씩스밀
# 익선동 익선주택
#
# 단 거 진짜 안조아하는데 . . 예외 탕  아이스크림두 꾸덕하니 입에서 살살 녹구 많이 달줄 알았는데 딸기가 적당히 잡아주는 맛이 있음 ㅜㅜ !!! 분위기도 쪼아요 ♡
# --------------------------------------------------
#  익선동 저스트텐동
#
# 그냥 텐동 맛 바질드레싱 올라가는 샐러드가 맛있음 다른 지점에 비해서 비싼듯? 토마토절임이 별로였다... 상콤한 유자,레몬청 좋아하면 좋아할맛 양은 많음!
#
# #먹다가_해찬이_생각이나신거예요
# --------------------------------------------------
#  익선동 롤인익선
#
# 연어아보카도롤이랑 치킨가라아게동 먹었는데 둘다 넘 맛있었어요 (༶ૢ˃̵̑◡˂̵̑༶ૢ)  특히 연어아보카도롤은 연어가 하나도 안비리고 양도 많았어요 !
# #정우의_원데이식스밀 #정우의_원데이씩스밀
# --------------------------------------------------
#  익선동 익선주택
#
# 여기 딸기 와플 진짜 맛있어요 ..  와플 진짜 부드럽고 아이스크림이랑 시럽이랑 같이 올려서 먹으면 걍 하나 금방 뚝딱 해치울수 있습니다 .., 음료들도 진짜 맛있었어요 !!
# 제 최애 카페 등극
# #정우의_원데이식스밀 #정우의_원데이씩스밀
# --------------------------------------------------
# #정우의_원데이식스밀
#
# 종로 익선동 아담집 !
# 공간은 크지 않지만 사장님도 친절하시고
# 안주도 맛있어서 만족도 최강 ,, 이였서요
# 문어초회 오꼬노미야끼 둘 다 추천,,
# 익선동 술집 고민하식 때,, 들릴만 합니다,,
# --------------------------------------------------
# #먹어봤도영
# #ㅌㅇㅌㅇㅈ
# #재혀니_맛있게머겅
#  익선동 이태리청년
#
# 프랜차이즈! 피자가 이렇게 돌돌 말아서 나오는데 걍 JMT
# 근데 먹기 좀 힘들당...
# 리조또나 다른 파스타도 맛있다!
# 인선동 골목골목이 넘 이뻐서 사진 찍기도 좋다 인생샷 많이 건짐!
# 추천
# --------------------------------------------------
# 익선동 121
#
# 동기언니 서울 투어 해주고 왔당
# 서울 투어라고 서울시티 뎡이 데려왔다ㅋㅋㅋ
# -카레 맛집
# #우와_저맛집유맹해 #도영이의유맹맛집 #먹어봤도영
# --------------------------------------------------
# 익선동 청수당
#
# 천혜향 청수(에이드)랑 딸기 수플레 카스텔라 무조건 잡숴. 존맛임
# #정우의_원데이식스밀
# #정우의_원데이씩스밀
# --------------------------------------------------
# #크리스_배고파용
# 익선동 온천집
# 건강한 맛
# 가격에 인테리어도 포함
# --------------------------------------------------
# 익선동 청수당
#
# 천혜향 에이드랑 딸기 프로마주 케이크가 정말 맛있음 카페 분위기 너무 예쁘고 물소리 들을 수 있어서 좋음!! 평일에도 사람 많아서 자리 잡기 힘들지만 기다릴만한 보람있는 카페
# #우석아_맛집으로_우따따따
# --------------------------------------------------
# #정우의_원데이식스밀
# 익선동 하이웨스트
# 분위기 굿~ 케익 귀여움
# 분위기랑 빵이 레이어드랑 비슷해
# 스콘이랑 케익이 있음
# --------------------------------------------------
#  익선동 청수당
# 익선동 핫플 다녀왔습니다용~ 자리도 운좋게 바로 잡을 수 있어서 넘 좋았음!! 케이크 맛있긴헌디 가격이 쫌 비싸영…!! 천혜향 청수는 에이드 느낌이고 상큼하게 먹었음~ 사진 찍으러 가는 곳인듯!! 분위기 맛집~~
#
# #정우의_원데이식스밀
# #정우의_원데이씩스밀
# --------------------------------------------------
#  익선동 돈부리파스타
# 운좋게 웨이팅 없이 다녀온 곳 !! 비스크 오제 파스타랑 갈릭 스테이크 돈부리 라이스 먹었는데 둘 다 넘 맛있었어!! 특히 로제 소스가 맛있었음 가게가 시원해서 짱짱 좋았음
# #정우의_원데이식스밀
# #정우의_원데이씩스밀
# --------------------------------------------------
#  종로3가 익선동 익선주택
# 홍콩식 와플 백만년만에 먹으러왔당
# 메론소다도 넘 시원하고 계절과일 복숭아 청포도 블루베리 조화 넘 좋아
# 조이 어멈이랑 냠냠긋
# #성찬이의_진수성찬
# --------------------------------------------------
#  익선동 백스트리트피자 / 카페온화
# 새우통통 감튀단짠 최고의 조합이였어요,,,레알 개맛있는 피맥집>_< 쉬림프+포테이토로 하프앤하프 찐추천!!!×913
# / 수플레맛집이라 찾아갔는데 포실포실하고 저 설탕 입힌 바나나랑 찰떡이였어요! 내부도 넓고 완벽
# #성찬이의_진수성찬
# #食中食_TEN
# --------------------------------------------------
# #성찬이의_진수성찬
# 익선동 백스트리트
# 여기 감튀랑 새우 반반 피자가 진짜 미쳤으니까
# 성차니두 숑프도 꼬옥 먹어주기 ~
# --------------------------------------------------
#  종로 3가 익선동 살롱 순라
# 버섯 메뉴들 많이 시켰는데 버섯 향 장난 아니게 좋아
# 순식간에 다 해치운 젠프 픽 맛집
# 와인 쿨러 이름이 달빛 순라인데 이름도 너무 예쁜
# #성찬이의_진수성찬 #MINTDAILY
# --------------------------------------------------
# #나나챌린지 #재민아_밥먹어
# 익선동 에일당
#
# 매콤까르보나라 파스타 맛집!
# 칠리 치즈 프라이도 맛있음!
#
# 맥주 맛집이라는데 다음엔 맥주를 먹어봐야겠다!
# --------------------------------------------------
# #먹어봤도영
# 요긴 익선동 카페 틈
# 익선카페 특유의 분위기도 좋고 사람도 많이 없어><
# 핸드드립 커피가 양도 많고 맛있구 레몬청은 덜 달아서 좋아
# 디저트는 얼그레이케이크!!
# --------------------------------------------------
# #먹어봤도영
# 종로3가 익선동 롤인익선
# 새우덴뿌라롤에 오이있다
# 연어아보카도롤은 원래 아보카도 안먹는데도 맛있다
# --------------------------------------------------
# #정우의_원데이씩스밀
# 익선동 [ 열두달 ]
#
# 파스타 이름은 기억 안나는데 양은 좀 적었지만 엄청 맛있었구 피자는 오곡크런치 고르곤졸라피자야.. 넘 맛있었어 ~~! 웨이팅이 좀 있긴 한데 진짜 JMT 정우도 먹어봐 >_<
# --------------------------------------------------
#
# #우석아_맛집으로_우따따따
# 종로 종각 익선동 #마스터플랜
#
# 뭐야,,,? 종로에 이렇게 맛있는 피자집이 있으면 말해 줬어야지 왜 다들 말해주지 않은 거죠? ૮( ᵒ̌▱ᵒ̌ )ა 진짜 이 근방 피자 중에는 제일 맛있다고 자부합니다... 치즈가 어떤 치즈인지 식어도 너무너무 부드럽고 맛있었어요!
# --------------------------------------------------
# #동현이를_위한_대동맛지도
# [익선동-호텔 세느장] 여기는 호텔 테마 카페라서 인테리어가 굉장히 독특했어! 동현이랑 멤버들이 재미있게 봤다는 호텔 델루나 촬영지였던 곳이래 예쁜 디저트들이 많은데 이곳은 까눌레가 제일 유명하다고 해
# --------------------------------------------------
# 익선동 비건인사 채식당
#
# 떡만두국&누룽지 버섯 탕수&후라이드 콩치킨
#
# 실내는 너무 더웠지만 맛있었다묘...
# 깜찍이 사슴이 반겨주는곳...
# #영현아_여기서도_7인분_어때 #케상트
# --------------------------------------------------
# 종로 익선동 도모다찌라멘
#
# 라멘 맛집 (｡◝▽◜｡) ♡
#
# #아기빵_크림채워
# --------------------------------------------------
# 익선동
# #리노는_배고파
# #현이도_먹어봐
# --------------------------------------------------
# 행복한 데이뚜
# 다음엔 더현대 뿌시기
# 익선동 이태리총각
# 창덕궁
# 익선동 라미스콘
#
# #캐럿들_여기_캐맛있어
# #디노야_케이밥의_미래
# --------------------------------------------------
# 충무로 분카샤
# 익선동 리장수라운지
#
# 분카샤 떡볶이 제발!!! 드셔보세요...
# 제 인생 떡볶이입니다...
# 후르츠산도 파는 그 카페 맞습니다...
#
# #현이도_먹어봐
# --------------------------------------------------
# 지미 스모크 하우스
# 그랑비노
#
# 베이비와 익선동 데이트
# 진짜 밥도 술도 다 맛있긴 했는데 걍 개같이 수다 떤 게 메인
# 집 들어가서 스스 켜주셈
# @_lily_magnolia_
#
# #ㅂㅅㅈㅇㅈ
# #eaj_말고_eatj
# #영현아_여기서도_7인분_어때
# #나나나나_원필이가_먹을래
# #도우니_밥묵었슴까
# --------------------------------------------------
# 익선동 행아웃
#
# 친구들아 청포도 에일 개맛있다 꼭 먹어
#
# #아기빵_크림채워
# #한이의_한입거리
# #이_식당은_진심으로_하늘이에요
# #현이도_먹어봐
# #리노는_배고파
# --------------------------------------------------
# #리노는_배고파
#  익선동 익선애뜻
#
# 강된장 쌈밥이랑 항정구이 비빔밥 맛있엉용
# 음식맛이 깔끔해서 완전 만족스러웟던 ..
# --------------------------------------------------
# 익선동 '오죽이네'
#
# 마늘맛팍팍느낄수있는 닭매운탕
# 진짜 한잔같이해줘야만.....
# ( @sibiflaw )
#
# #여기맛있승민
# #아기빵_크림채워
# #멍빵_딜리셔스
# --------------------------------------------------
# 익선동 WOO'Z
#
# 딸기 트라이플 최고 최고
# #우지를삼킬순없잖아
# #캐럿들_여기가_캐맛있어
# --------------------------------------------------
# 익선동 온천집.
# 웨이팅 2시간 넘게했는데 후회없었다
# 개인 1인팟에 채소랑 고기랑 보글보글 끓여서 호로록 계란노른자+소스에 퐁 찍어먹으면 최고최고
# #우지를삼킬순없잖아
# #캐럿들_여기가_캐맛있어
# --------------------------------------------------
#  익선동 오늘그대와
#
# 라구 리조또랑 초리죠(오일파스타) 먹었음 짱마시써~~ 느끼하지도 않고 배부르게 잘 먹고왔습니다.ᐟ.ᐟෆ
#
# #우리배는_식도로만_가
# #최산을_다해_먹어봐요
# #밍하오야_여기_헌하오츠
# 캐럿소녀가포카놓고옴..
# --------------------------------------------------
# 익선동 노가리슈퍼
# 날좋아서 노상하기 최고
# #캐럿들_여기_캐맛있어
# --------------------------------------------------
# 익선동 빠리가옥
# #캐럿들_여기_캐맛있어
# --------------------------------------------------
# 익선동 워터밀
#
# 비건 메뉴로도 변경 가능하고 인테리어도 깔끔하고 예뻐요
# 갈릭 명란 오일 스파게︎티니︎︎❤︎ 꼭 드세여!!
#
# #우리배는_식도로만_가
# #산맛집
# #최산을_다해서_먹어봐요
# --------------------------------------------------
# 익선동 익선주택
# 홍콩식 와플 파는 곳! 와플 맛있고 음료도 존맛,,,메론소다는 꼭 시켜주면 되..... ♡
# 근데 주말에 가니까 웨이팅 좀 있었음 ㅜㅠ
# #영현아_여기서도_7인분_어때
# --------------------------------------------------
# 익선동 마츠노하나
# 텐동 쪼오오온맛!!! 솔직히 튀기면 다 맛있음,,,,
# 내가 시킨건 쇼유사케에비텐동 ! 연어랑 튀김 반반이고 친구는 호르몬에비텐동인데 오히려 대창이 매콤해서 덜 느끼하다함!!!! 텐동 좃타,,, ♡
# #영현아_여기서도_7인분_어때
# --------------------------------------------------
# #우지를삼킬순없잖아
# 익선동 익선주택
#
# 와플이 진짜 너무 맛있어요 익선동 오시면 꼬옥 홍콩와플 드세용
# --------------------------------------------------
# #우지를삼킬순없잖아
# 익선동 롤인익선
#
# 느끼하지도 않아서 먹기 너무너무 좋아요 연어 좋아하시는 분들이라면 꼭 가보세용 다만 가게가 조금 협소해서 여러명이 가기에는 비추
# --------------------------------------------------
# 익선동 익선주택
#
# 홍콩와플 맛집이에요.. 같이 나오는 아이스크림이 맛없는 아이스크림이 아니라 진짜 맛있는 아이스크림!!! 이고 바나나도 짱 넉넉히 들어가있어요 분위기도 좋고 음료는 딸기라떼 추천합니댜!!!
# #여기맛있승민
# --------------------------------------------------
#  카페 오타르
#
# 에그타르트가 최고 맛있는 익선동 카페!
# 에그타르트 뿐만 아니라 음료도 너무 맛있었어요 >.<
# #리노는_배고파
# #보민아_여기가극락인가봄
# #우지를삼킬순없잖아
# --------------------------------------------------
# 익선동 카페 온정
#
# 수플레 전문 디저트 카페인데 같이 간 사촌언니도 맛잇다 햇고 차도 따땃하고 맛잇음 수플레는 당연히 존맛 근데 좀 비쌈
# 우리는 차 두잔+벌꿀수플레 시킴
# 나오는데 시간이 20분정도(수플레때문에
#
# #우리배는_식도로만_가
# --------------------------------------------------
# 익선동 리치몬드딤섬
# 딤섬 진짜 맛잇고 특히 고거 새우들어간게 진짜 존맛
# 직원분도 친절하시고 분위기 좋음
#
# #우리배는_식도로만_가
# --------------------------------------------------
# 익선동 온천집
#
# 얼큰샤브3단, 유자막걸리
#
# 춥지만 매년 겨울마다 웨이팅 기다려서 먹을만한 곳
# 기다리는 동안 포토존에서 예쁘게 사진 찍으면 시간 순삭이에요
# 친절한 서비스와 가게 안에 연못이 보이는 인테리어가 인상적인 가게
# #우리배는_식도로만_가
# #강여_상당히맛있는집
# --------------------------------------------------
# 익선동 온천집.ᐟ.ᐟ.ᐟ
# 얼큰샤브샤브에 유자 막걸리 한잔 하면 이번 겨울도 ㅇㅋ
# #우리배는_식도로만_가
# #강여_상당히맛있는집
# #강여상_치킨말고_이것도_먹어봐
# --------------------------------------------------
# #우리배는_식도로만_가
#  익선동 백스트리트피자
#
# 진짜백스트리트에있어서 쪼꼼당황했지만
# 감튀페퍼로니새우등등 토핑빵빵피자가맛있고
# 고구마튀김&치즈볼사이드가친절해요
# --------------------------------------------------
# 익선동 익선주택
# 계절과일이 올라간 홍콩식와플
# 청포도에이드 마시ㄸㅑ !!
#
# #리노는_배고파
# #영현아_여기서도_7인분_어때
# --------------------------------------------------
# 익선동 롤인익선
# 가성비 연어맛집 .ᐟ.ᐟ
# 둘이서 메뉴 세개 먹었는데
# 이만원 중반 가격으로 먹었어요
# 디노는 오이 싫어하니까 롤은 빼고 먹으면되 ..
# #디노야_여기_케이밥의_미래
# #정우영_맛있게_먹우영
# #우리배는_식도로만_가
# --------------------------------------------------
# 해피치즈스마일 익선동
#
# 유명한덴 이유가 있더라구여 진짜 캐존맛 !!!!
# 근데… 둘이서 먹으면 많다구 해서 약간 긴장했는데 너무 쉽게 둘이서 다먹음..
# 아무튼 춫천합니다 !!
# #여기맛있승민 #한이의_한입거리 #리노는_배고파
# --------------------------------------------------
# 서울커피 익선동
#
# 한옥 분위기가 이쁘고 커피는 산미 없이 깔끔해요!! 비엔나밀크티는 크림 진짜 부드럽고 진짜 맛있었어요!!!
# 앙버터식빵은 4500원치고 크기가 쫌 오바..
# #여기맛있승민 #한이의_한입거리 #리노는_배고파
# --------------------------------------------------
# 청수당 (익선동)
#
# 딸기 수플레도 맛있고 커피도 맛있어요
# 비 오는 날 운치 작렬 ( ⁎ᵕᴗᵕ⁎ )
#
# #리노는_배고파
# --------------------------------------------------
# 익선동 라미스콘
#
# 비건스콘으로 유명한 라미스콘
# 치즈수플레랑 브라우니 시켜서 먹었는데 진짜 대박이에요.. 수플레가 글루텐 프리인게 안믿겨지는 맛
# 브라우니도 최고
# 스콘 종류도 엄청 다양해요
#
# #이_식당은_진심으로_하늘이에요
# #리노는_배고파
# #현이도_먹어봐
# --------------------------------------------------
# 익선동 돈부리파스타
# #우리배는_식도로만_가
# #최산을_다해서_먹어봐요
# --------------------------------------------------
#  익선동 롤인익선
#
# 정말 최고
# 긴 말이 필요 없어요
# 연어가 진짜 미쳤습니다...
# 입 안에 연어가 꽉 들이차요
# 새우도 진짜 대박이에요
# 가성비
# #나는_너의_밥선생
# #eaj_말구_eatj
# #영현아_여기서도_7인분_어때
# #나나나나_원필이가_먹을래
# #도운이_밥묵엇슴까
# --------------------------------------------------
#  익선동 틈 (teum)
#
# 샹그리아 짱맛집!! 친구가 추천해줘서 가봤는데
# 지금까지 먹어본 샹그리아중에 제일 맛있었어요 !! 수제맥주도 맛있대서 다음엔 그거 먹어볼 예정 .. 이름처럼 진짜 틈 사이에 있으니까 잘 찾아가보시길
#
# #리노는_배고파
# --------------------------------------------------
# 익선동 롤인익선 ❀ུ۪
#
# 연어초밥 너무 부드럽구
# 비린거 하나도없이 맛나요 (ˊᗨˋ)!
# 모두 맛점 ♡︎ 사니도 맛점 ♡︎
#
# #우리배는_식도로만_가
# #산맛집
# #최산을_다해서_먹어봐요
# --------------------------------------------------
# 익선동 호호식당 카츠나베
# 따숩고 맛나용 밥도 한 공기 줘서 양 많음
# #영현아_여기서도_7인분_어때
# --------------------------------------------------
#  익선동 - 기러기둥지
#
# 너무 맛있었던 바베큐 플레이트랑 크림소스 감자 뇨끼  와인바인데 가격도 괜찮은 편이고 매장 내부가 너무너무 예쁘게 꾸며져 있어서 밥 먹는 내내 너무 황홀했던
# #여기맛있승민
# --------------------------------------------------
# #여기맛있승민
# #리노는_배고파
# #현이도_먹어봐
# 익선동 호텔세느장
#
# 카페 분위기 개미쳤고 진짜 호텔을 카페로 바꾼거라 컨셉이 뚜렷해서 이쁨.. 5층까지 있어서 좋음
# 호텔 델루나 생각나는 곳임.. 현진이 완전 좋아하겠다
# 암튼 저 딸기 수플레 크림이.. 미쳤음.. 재방문 의사 100프로 ♡
# --------------------------------------------------
# #여기맛있승민
# #리노는_배고파
# 익선동 백스트리트 피자
#
# 이미 유명해서 무슨 말이 더 필요할까 싶지만
# 정말 정말 미친놈임.
# 저 새우. 존나. 흉악범. 뭐 그런거임.
# 진짜 개탱글탱글하고 꼭 시켜요
# 맥주는 스트로베리어쩌구 시켰는데
# 표현할 수 없는 맛이라 줏대있게 시켜보고 판단하면 될듯
# --------------------------------------------------
# 익선동 <익선디미방>
#
# - 청양고추 해산물 부야베스 파스타
# - 간장양념 수비드 닭다리살 스테이크
# - 고르곤졸라 크림 스테이크 리조또
#
# 각 메뉴마다 들어가는 재료도 실하고 깔끔해서 맛있었던 곳.
#
# 들어가는 길, 매장크기가 좁고 웨이팅이 많은거 감안하기!
#
#  #디노야_여기_케이밥의_미래
# --------------------------------------------------
# 피자 맛집
#
# 압구정 노모어 피자
# 연남동 랫댓
# 익선동 백스트리트 피자
# 홍대 더피자보이즈
#
# #여기맛있승민
# #리노는_배고파
# --------------------------------------------------
# 익선동 백스트리트 피자
# 이미 맛집으로 유명한곳 진짜 새우가 통통한게 미친놈(Ex)임... 새우반 감튀반 추천
# #이_식당은_진심으로_하늘이에요
# #아기빵_크림채워
# --------------------------------------------------
# 익선동 익선주택
# 홍콩와플이 존맛인곳 한옥같은 빈티지 인테리어라 분위기도 짱짱
# #이_식당은_진심으로_하늘이에요
# #아기빵_크림채워
# --------------------------------------------------
# 익선동 하이웨스트
# 짱맛있고 예쁜 디저트 많은 카페
# 분위기도 넘예뿜♡♡
# #이_식당은_진심으로_하늘이에요
# #아기빵_크림채워
# --------------------------------------------------
# #아기빵_크림채워
# 익선동 카페온화
#
# 웨이팅이 있는편이고 바나나가 넘 맛있었어 사진 찍기도 딱 좋은곳
# --------------------------------------------------
# #아기빵_크림채워
# 익선동 롤인익선
#
# 연어초밥 6피스에 6900 연어킬러들은 무조건 가야하는 맛집이야 가게가 작아서 웨이팅이 있는편 ㅠㅠ 우삼겹 우동도 너무 맛있었어 정인이도 꼭 가봐
# --------------------------------------------------
# #아기빵_크림채워
# 익선동 백스트리트 피자
#
# 여기서는 꼭 쉬림프랑 포테이토 반반을 먹어야해 쉬림프는 좀 매콤 하다면 포테이포는 달달해 4명이서 갔는데 4인 시키니까 피자가 엄청 컸어 꼭 2-3인 시켜
# --------------------------------------------------
# #아기빵_크림채워
# 익선동 돈부리 파스타 웨이팅이 있는편이야 파스타 맛이 진짜 최고야 가게 분위기도 너무 좋은곳이야 나는 새우 파스타를 먹었는데 진짜 맛있었어
# --------------------------------------------------
# #아기빵_크림채워
#  익선동 밀토스트
#
# 짱인이처럼 포슬포슬 말랑말랑한 스팀 식빵이랑 수플레 토스트가 맛있는 곳이야 .ᐟ.ᐟ  찜기에 담겨 나오는 식빵은 완전 촉촉하고 수플레 토스트도 정말정말 부드러움 .ᐟ.ᐟ 커피도 전부 드립이고 아몬드모카 크림커피 추천해
# --------------------------------------------------
# 익선동 에일당
# 안주랑 수제맥주가 맛있는데 둘이 먹기엔 많음
#
# #우리배는_식도로만_가
# #박성화_이것좀_먹어보라고_성화
# --------------------------------------------------
#  익선동 우연화
#
# 오랜만에 서울 나들이••
# 숯불향 가득한 함박스테이크 맛집,,
# #너에게_내_밥상을_줄게
# #예찬이짱짱맨
# #상엽아_다람쥐는_이거못먹겠지
# #원상아_여기_알라빙빙
# #이게_내_마지막_밥이라고
# --------------------------------------------------
# 익선동 익선문구사
#
# #봉재현_이건_먹겠지
# #재현아_내_맛집을_받아줘
# --------------------------------------------------
# @CONG_LING_
# --------------------------------------------------
#  익선동 호호식당
#
# 여기는 진짜진짜 맛있음.. 히레카츠 추천
# 룸 예약하고 가면 쪼아요
# #용훈이_얼굴만큼_기대하고가도되는곳
# #웅이가_맛보면_좋겠웅
# --------------------------------------------------
# 맛잘알 미션하듯 익선동 뿌시고옴
#
# 르블란서
# 시그니처알
# 치킨뱅이
# 술라
#
# #윤성아_혼자_먹기_아까워
# #주창욱_넌_안먹어봤겠지
# #주찬_넌이미여기서쫓겨났겠지
# #장준아나중에밥이나한끼하자
# --------------------------------------------------
# 종로 익선동 온천집ఇ
#
# 처음에 나왓을ㄸㅐ 엥 .. 이게 1인분? 했는데 먹다보면 배부름 !! 된장샤브 얼큰샤브 있는데 저는 얼큰샤브 먹엇고요 .. 고기추가 면사리추가햇음 근데 면사리말고 야채추가하는게 나을듯.. 배터져효
# #장준아나중에밥이나한끼하자
# --------------------------------------------------
# 익선동 롤인익선
#
# 랜다시 갔다가 천천히 걸어가도 좋은 곳
# 연어 좋아하시면 무난하게 좋아하실 거 같아요 두명이서 가시면 연어 6피스 하나만 시키셔도됨。。 주말 12시쯤엔 웨이팅 없이 들어갔어요!
#
# #박성화_세입컷챌린지
# --------------------------------------------------
# #이맛집은신이에요
# 익선동 온천집 샤브샤브!!!! 분위기조아
# --------------------------------------------------
# #이맛집은신이에요
# 익선동 온천집
# --------------------------------------------------
# 익선동 롤인익선
#
# 밥 시간에는 웨이팅 좀 긴것같앙요!!!!
# 피크타임 피해서 가는거 추천..
# 초밥이 생각보다 커서 둘이서 배불리 한판 해치웠음
# #장준아나중에밥이나한끼하자
# --------------------------------------------------
# #지범_맛집다녀오겠습니다
# 익선동 롤인익선
#
# 지범아 여기 종로3가역 근처에 있는 연어맛집 롤맛집...
# 연어초밥 6pcs에 6900원인데 가성비 짱짱.ᐟ.ᐟ 연어도 두툼하고 커서 넘 맛있고 담에 또 오고 싶었던 집이야 ♡
# --------------------------------------------------
# #지범_맛집다녀오겠습니다
# #주찬_넌이미여기서쫓겨났겠지
# 익선동 돈부리파스타
#
# 요즘 익선에서 가장 핫한 곳이얌
# 식사시간보다 살짝 일찍가면 웨이팅없더랑!
# 대창호르몬매콤파스타도 로제같이 맛있고
# 대창에 와사비올려서 명란크림파스타랑 먹으면 미틴넘이야... 익선동 갈일있으면 가보기
# --------------------------------------------------
# #문득생각해석진이가이걸먹어봤을까
# 익선동 카페하이웨스트
# 모양만 이쁜줄알앗는데 생각보다 맛잇어서놀람 쿠키맛집임
# --------------------------------------------------
# #정원이_볼살로_레쭈고
# #오늘의_제이
# #성훈이_입속으로_트리플악셀
# 익선동 에일당
# 해운대 타르트훌리건
#
# 급하게 서치하고 다녀온 에일당… 너무 맛있었다 밤에는 술집으로 운영되는 듯! 가격도 쏘쏘
# 글고 내가 제일 좋아하는 타르트훌리건…
# 해운대 가게된다면 꼭!!! 사오세요 여러분…
# --------------------------------------------------
# 익선동 백스트리트 피자
#
# 피자 잘안먹는데 맛있어서 거의 다 먹고온 !!
# 새우가 진짜 맛있어요
# (감자튀김은 먹다보면 좀 달어요)
#
# 가게가 작아서 잘 안보여서 지나칠뻔한 ㅋㅋㅋㅠ
#
# 가게 내부가 어두워서 혹시나 가시면 내려갈때   계단 조심하세요 ㅠ !
# #먹으면_서로_윈윈
# #이거맛있뎨
# --------------------------------------------------
# 월요일에 먹은 수플레 팬케익!
#
# 익선동 온화 라는 카페 였어요 인테리어가 예뻤고 수플레 완전 보들보들해서 행복했어요
# 지점 여러군데 있으니 근처 지점 찾아보셔도 좋을거 같아요
#
# #팻앤슈가챌린지
# #효앞꾸먹 #이션같이찌자
# #어스맛집여기있으 #엇대먹
# #수박민균 #유토야_딸기먹자
# --------------------------------------------------
# ✿퓨즈 디데이 문답ꕤ*.ﾟ
#
# ✧*.◟ℚ.𝟡◞.*✧
# 발렌타인데이입니다!
# 공유하고 싶은 카페와 디저트 자랑, 추천해주세요!
# #팻앤슈가챌린지 도 동참해주세요!
#
# #온앤오프 #ONF #온앤오프디데이 #온앤오프디데이9 #퓨즈디데이 #퓨즈디데이9
# --------------------------------------------------
# 익선동 청수당
#
# 유명한 곳은 이유가 있다
# 비싸지만 그만큼 너무너무 맛있는 딸기수플레
# 미니모도 꼬옥 먹어주기
# #미니미니미니_강쥐는먹으면안돼용
# #정모야_맛집_뒤집자
# --------------------------------------------------
#  익선동 돈부리파스타
#
# 재윤이 생일 너무너무 축하해
# 럽유~~
# #제이크에게_메뉴추천
# #정원이_볼살로_레쭈고
# #무대천재_엔하이픈_제이크_생일축하해
# #OurJAEYUNiverseDay
# --------------------------------------------------
# 익선동 백스트리트 피자
#
# 새우랑 감자가 징짜 존맛!!
# 새우알러지 있는데도 맛있게 머금..(엥?
# 근데 직원분 입에 풀칠하신줄..
#
# #오늘의제이
# #엔진예절
# --------------------------------------------------
# 21.10.28 익선동 맛집 탐방
# 익선동 거리 이곳 저곳 누비다 메뉴판만 보고 이끌리는대로 선택했던
# 뭘먹든 잘먹는 우리 ㅎㅎ 그래도 실패없이 맛있게 잘먹고 놀았다
# 언제나 함께 하면 즐겁고 시간 가는줄 모르는... 곧 또 봐요
# #효앞꾸먹 #이같찌
# --------------------------------------------------
# 익선동 청수당! 내부 외부 둘 다 너무 예뻤던 카페에요 딸기 카스테라도 따끈따끈하니 너무 맛있었던..! 딸기카스테라 말고도 다른 종류의 카스테라도 많으니까 꼭 취향대로 드셔보시길 추천합니다 #정국아_같이먹짱
# --------------------------------------------------
# 익선동 롤인익선
#
# 연어초밥 연어아보카도롤 판모밀 왕추천~!!
#
# #가든_맛집
# --------------------------------------------------
# #정국아_같이먹짱 #정국 #JUNGKOOK
# 독립밀방
# 분위기 짱 가격대 있는 편이지만 양도 괜찮고 맛있음∩( ´∀` )∩
# (익선동 익선잡방 3번째 지점)
# --------------------------------------------------
#  익선동 르블란서
#
# 라구파스타랑 로스티드 치킨이 맛있어용
# #엔진예절
# #오늘의제이
# #성훈이_입속으로_트리플악셀
# #정원이_볼속으로_레쭈고
# #니시무라_마니무라
# --------------------------------------------------
# 익선동 익선주택
# 홍콩와플전문점 바나나누텔라 먹었어용 바나나브륄래가 정말 미친놈♡
# #미니미니미니_강쥐는먹으면안돼용
# --------------------------------------------------
# 익선동 돈부리파스타
#
# 곱창파스타라는 특이한 메뉴가 있는 곳
# 뭔가 느끼할거같은 조합이지만 소스에 청양고추도 있고 매콤해서 은근 잘어울림
# 곱창 완전 곱 실하게 들어있음 곱창맛집 #미니미니미니_강쥐는먹으면안돼용
# --------------------------------------------------
# #창윤아내가다계산할게먹기만해
# #이션같이찌자 #효앞꾸먹
# 익선동 백스트리트피자
# 새우가 엄청 실하고 포테이토가 진심 너무 내취향
# --------------------------------------------------
# 이미 또 졸라 유명한(ㅋㅋ) 혜화인가 익선동 호호식당! 그냥.. 먹을만햐~ 근데 웨이팅 개지림 세시간 ㅇㅈㄹ이엇는데 요샌 모르겠음.. 그냥 적당히 맛있고 잉스타 감성임~!  #문득생각해석진이가이걸먹어봤을까
# --------------------------------------------------
# 피자 먹으러 와써요 ~
# 잘 먹겠습니다아ㅏㅏ
#
#  익선동 백스트리트피자
#
# With @516zzang
# #동표야_넌이거못먹지
# #시영이가_생각나면_올릴게요
# #쭌쭌같이밥드쉴
# --------------------------------------------------
#  익선동 익선주택
#
# 멜론소다랑 바나나누텔라 홍콩와플! 와플 양도 많고 퐁신한 팬케이크 같아요  좌석이 그렇게 많지는 않지만 카페 내부도 고급지고 예뻐요 완전 추천!
# #재혀니_맛있게머겅
# --------------------------------------------------
# #지원아밥메건니
# #여기먹어볼새롬
# #꿀깅아_여기_꿀발랐다
# #지선아_누가1인분만먹고살아_미친거지
# 익선동 “해피치즈스마일”
# 저어어어언부터 먹고싶어서 벼르고 잇던 집인데 드디어 오늘!!! 가서 먹구왓어요 떡볶이 떡을 튀긴 튀볶이가 잇엇는데 겉은 바삭하고 속은 부드러워서 진짜 최고엿어요..
# --------------------------------------------------
# #지원아밥메건니
# #꿀깅아_여기_꿀발랐다
# #여기먹어볼새롬
# 익선동 “끼룩하우스”
# 여기는 제가 너무너무너무너무 조아하는 카페~♡ 저 예쁜 음료 이름은 끼룩에이드!! 레몬에이드에요~ 다 섞고 나서도 예쁜 보랏빛이구 맛도 넘 조아요 짱추!!!합니다
# --------------------------------------------------
# #먹태일기릿
# #JMTforTAEIL
# 익선동 백스트리트 피자 ...
# 주문한 건 하프앤하프 쉬림프랑 포테이토
# 진짜 미친놈임 ...
# 여기에 스윗포테이토랑 치즈볼 먹으면 더 미친놈이에여
# --------------------------------------------------
# #기범아_나혼자먹는거_아니야
# #태민_DO_EAT_BABY
# #태민아_맛집_보고드립니다
# 종로3가(익선동) 시그니처알
#
# 돌아다니다 우연히 들어간 한옥 카페한적한 분위기도 좋고 중앙정원에 짱귀여운 고양이도 있다 자몽에이드 맛있었음
# --------------------------------------------------
# #기범아_나혼자먹는거_아니야
# 종로3가(익선동) 오죽이네
#
# 1주일만에 재방문 했어요
# 우동사리랑 볶음밥 맛있어요
# 다음주에 또 갈게요
# --------------------------------------------------
# 익선동 솔솥
# 11시20분에 갔더니 대기표 8번 받음
# 버터 들어가서 고소하고, 누룽지도 맛있고
# 사진메뉴는 전복솥밥
# 찬이 많은 편은 아니지만 적당한 너낌
# 가격: ₩15,000
# #종현이가_맛있는거_먹는게_좋아
# #기범아_나혼자먹는거_아니야
# #민호야_식단관리_이겨내
# #태민아_맛집_보고드립니다
# --------------------------------------------------
#  익선동 - 카페 온
#
# 가마솥빵 부드럽고 맛있다 (｡☌ᴗ☌｡)
#
# #인성아나이거오분순삭
# #인성아배고파
# --------------------------------------------------
#  익선동 틈
#  익선동 빠리가옥
#
# 어쩌다가 셒구투어하게됨♡
#
# #태양아_이거어때_난좋은데
# #영균아_먹어보지_않을래
# #영균아_뭐라도_먹어봐
# #옴뇸뇸소리안나요
# --------------------------------------------------
# <익선 익선취향>
#
# 딱 익선동 같아요 ㅎㅎ 음식 다 괜찮은 거 같아요!! 파스타 맛있음  가게도 예쁘고 감성 충만해요
# #이션같이찌자
# --------------------------------------------------
# 경주 황리단길 온천집
# 된장 육수랑 얼큰 육수 있는데 얼큰한 건 커리 느낌이 남!! 1인에 1.8이었고 덮밥 메뉴들도 있는데 저희는 샤브샤브만 먹었어요 웨이팅 있음 익선동이랑 다른 지역에도 있는 걸로 알고 있어용
# #jaeyoon_BSMR #저는잘먹을수있어요
# #태양아_이거어때_난좋은데
# --------------------------------------------------
# 익선동 시그니처R
# 유명한 카페들은 자리가 없길래 우연히 들어간 곳인데 넘 만족했던!! 그린애플 에이드 맛있었고 케이크도 두 종류 다 맛있었어용 그리고 매장이 넓고 테이블 간 간격이 넓어서 좋았음
# #저는잘먹을수있어요
# #태양아_이거어때_난좋은데
# --------------------------------------------------
# 익선동 빠리가옥
# 웨이팅 많아서 무조건 예약하고 가시는 걸 추천!! 예약하고 가면 한번쯤은 가볼 만한 듯! 리조또랑 파스타에 베이컨이랑 해물 완전 많이 들어있음 한우 타르타르는 프랑스식 육회라는데 개인적으로는 우리나라식이 더 제 취향이에요..
# #저는잘먹을수있어요
# #태양아_이거어때_난좋은데
# --------------------------------------------------
# 익선동 해피치즈스마일 .ᐟ
# 치즈세트 맛있ㄷ ㅏ
# #이션같이찌자
# #온앤오프_같이먹자 #온앤오프_짱먹자
# --------------------------------------------------
# 익선동 오레노 라멘
# #인성아나이거5분순삭
# #인성아배고파
# #저는잘먹을수있어요
# #재윤아_저는_잘_먹을_수_있어요
# #태양아_이거어때_난좋은데
# --------------------------------------------------
# 익선동 온천집
# 한옥으로 된 가게 분위기부터 너무 좋은 곳
# 수비드수육 된장샤브샤브 모두 엄청 맛있음 ><
# #어스_맛집_여기있으 #이승준먹방대결
# --------------------------------------------------
# 익선동 플로
# 피자맛집
# #인성아나이거5분순삭
# #인성아배고파
# #저는잘먹을수있어요
# #재윤아_저는_잘_먹을_수_있어요
# #태양아_이거어때_난좋은데
# --------------------------------------------------
# 익선동 익선주택
#
# 우리는 홍콩와플 잘 먹을 수 있어요 @babycocoball
# #얘두다나이거머금
# #태양아_이거어때_난좋은데
# #저는잘먹을수있어요
# --------------------------------------------------
# 익선동 하이웨스트서울
# 에어컨 굿
# 자연광 맛집
# 디저트가 많음
#
# #쟁턍의_맛난다_맛나
# #저는잘먹을수있어요
# #태양아_이거어때_난좋은데
# #녀석_오늘좀맘에드네
# --------------------------------------------------
# 익선동인지 돈의동인지
# 여튼 백스트리트 피자
# 새우가 왕크니까 왕맛있다!
#
# #쟁턍의_맛난다_맛나
# #저는잘먹을수있어요
# #태양아_이거어때_난좋은데
# #녀석_오늘좀맘에드네
# --------------------------------------------------
# #이션같이찌자
# 익선동 오죽이네 !!
# 사진이 쫌 .. 그렇지만
# 닭한마리 매운국물버전으로 생각하면 될듯
# 많이 맵지두 않고 국물이 맛있었음 굿굿~~~!!!!!!!!!
# --------------------------------------------------
# 익선동 백스트리트피자
# 익선동 온화
# 종로 경성상회
#
# #인성아나이거5분순삭
# #김석우_입으로_떼구르르
# --------------------------------------------------
# #영균아_뭐라도_먹어봐
# #영균아_먹어보지_않을래
# 여기 맛나㉰ 규나... 담에 차니랑 또 익선동
# 갈일 있으면 요기 먹어봐~ 돈부리 파스타
# --------------------------------------------------
# 종로 익선동
# 백스트리트피자
# -쉬림프&페페로니 하프앤하프
# -감자튀김&치즈볼
# 카페 온화
# -벌꿀 수플레&오몽에이드,아아
#
# 완맛완맛 재방문의사만땅
# #김석우_입으로_떼구르르
# --------------------------------------------------
# #이션같이찌자 #이승준먹방대결
# 부산에 안간 죄(?)로 익선동에서 쳐묵쳐묵
# 피자 너무 맛있음 ㅠㅡㅠ
# --------------------------------------------------
#  세컨디포레스트 익선점
#
# 익선동 골목에서 찾은 파스타집
# 에피타이저로 나오는 빵에 발사믹 소스는 너무 맛있어서 다 먹고 찍은 점 •••
# 너무 맛있어서 먹느라 예절샷을 저렇게 찍어버렸다 미안하다...
#
# #강이사님_드셔보세요
# #태현아_한번_맛볼테리
# #강이사님_이건_제가먹을게요_^_^*
# --------------------------------------------------
#  익선동 온천집
#
# 2시간 40분 웨이팅하고 들어감...
# 웨이팅할거면 일찍 해두는 게 좋을 거 같아요
# 맛있었어요 !!
# 겨울에는 샤브샤브
# 짱
# #준규_메롱 #라마x3 #오늘_하루토_맛있는_하루 #완전_got_a_lot_of_flame이야_완전_sick이야_완전_its_lit이야
# --------------------------------------------------
#  익선동 도넛정수
#
# 생각나서올리깅 여기 도넛이 쫀!!!!맛..
# #돼지 #돼지공키 #너애게내밥상을줄게 #이게내마지막밥이라고
# --------------------------------------------------
# 익선동 솔솥
# 장어어어어어
# 오늘도 배터지게 먹어보쟈고
# #쩝쩝박사_말랑이에게 #사나없이먹으나마나 #지효야나먹어쪄 #오늘묘먹지 #쯔버블 #마싯둡
# --------------------------------------------------
# [익선동] 도넛의 정수
#
# 진짜 너무너무 맛있어요
# 정신 못 차리고 5분만에 다 먹었어요
# 원래 있던 곳이랑 거리가 멀었는데도 굳이 들려서 먹은 보람이 있었어요
# #모아들의_맛집을_모아모아
# #최연준_맛집1등어디야
# --------------------------------------------------
# 익선동
# #최연준_맛집1등어디야
# #수빈아_먹어봐_마수리수리
# --------------------------------------------------
# 익선동 간판없는가게 ~.~
# @lovingbabya
# #허나아_밥먹자
# #먹어보세용_희희
# --------------------------------------------------
# #사나없이먹으나마나
# 익선동 목장 목살한판 삼겹살한판 @SeRam617 @romanceti9er @sonbadak29 @clumsy_saennim
# --------------------------------------------------
# 연준이도 먹어봤으면 좋겠네엥♡
# 아보카도안좋아하는데 너무 맛있게먹었던 곳
# 연어는 늘 옳음
# 익선동 롤인익선
# #최연준_맛집1등어디야
# --------------------------------------------------
# 익선동 <롤인익선>
# '연사모'라면 꼭 가야함
# 두툼한 연어가 입에서 사르르~
# 순식간에 기영이 face로 쁘띠성형 됨
#
# #수빈아_먹어봐_마수리수리
# #ㅌㅇㅌㅇㅈ
# --------------------------------------------------
# 익선동 워터밀
# 수경재배로 키운 채소로 만든 코스요리!
# 메인메뉴 1개에 알라카르테 4개 고를 수 있어서
# 다양하게 먹어볼 수 있는 게 좋았던
# 대좋맛
# #라마x3 #준규_메롱
# --------------------------------------------------
# 익선동 온천집 점심
# #지효야나먹어쪄
# #사나없이먹으나마나
# --------------------------------------------------
# 익선동 롤인익선 & 망원 암튼
#
# #정우야_여기_먹으러_꼭와
# #현석이_입맛이에 #지훈아_여기가봐라
# #마시호_여기가보시호
#
# 축하사절단이면서 생일 다 지나고 올리는 행위.. 롤인익선은 진짜 최고.. 카페 암튼은 음료랑 베이커리 다 맛있구 직원분도 엄청엄청 친절하샤서 기분이 좋앗답니다 강추
# --------------------------------------------------
#  익선동 롤인익선
#
# #정우야_여기_먹으러_꼭와 #라마x3
# #현석이_입맛이에 #지훈아_여기가봐라
#
# 가게가 좁아서 식사시간에 가면 웨이팅 해야함 ..  그치만 연어가 짱 두툼하고 완존 부드러움 .ᐟ.ᐟ 가격도 괜찮은 편 ♡ ! 연어드래곤롤 완전 추천.. (오이주의)우삼겹우동도 맛잇으요 @비누
# --------------------------------------------------
# 익선동 롤인익선
#
# #정우야_여기_먹으러_꼭와 #라마x3
# #현석이_입맛이에 #지훈아_여기가봐라
#
# 가게가 작기도 하고 사람도 많아서 웨이팅이 꽤나 길었음  하지만 가격대도 정말 괜찮구 맛도 최고!!  연어초밥 크기가 꽤 큼 ...  아 연어드래곤롤에는 오이가 있음...  오이 못 먹는 사람 주의!
# --------------------------------------------------
# #정환아_여기맛있소
# #이야아마시따아도영아
# 트맵에서 갔던
# 익선동 카페 온 (*˙˘˙)♡
# 빵이 부드럽고 비쌋어요
# 그치만 맛잇음 커피두 굿굿
# --------------------------------------------------
# 익선동 백스트리트 피자
#
# 쉬림프 포테이토 반반 진리 .ᐟ.ᐟ ♥︎
#
# #정환아_여기맛있소
# #이야아마시따아도영아
# --------------------------------------------------
# #지효야나먹어쪄 익선동 아트몬스터
# 맥주로 시작해서 맥주로 끝나는 하루 ><
# --------------------------------------------------
# #지효야나먹어쪄 익선동 크라프트 루 한옥 수제 맥주집이야 낮술에 식사 엄청하네... 킥킥킥....
# --------------------------------------------------
# #이야아마시따아도영아
# 익선동 백스트리트 피자
# ㅈㅔ일 와보고 싶던 곳 ,, 여기도 새우가 삐로통통이야아 ♡
# --------------------------------------------------
# #태현아 여기는 익선동에 있는 롤인익선  여럿이서 가서 종류를 다양하게 먹었는데! 개인적으로는 연어 아보카도 롤이 제일 맛있었어 >_< 와사비도 생와사비라 밥 종류랑 같이 먹으면  고기우동이랑 연어초밥도 정말 맛있더라!  #태현아_한번_맛볼테리
# --------------------------------------------------
# 크왕! 할 것 같은 생선통튀김이랑 미소홍게라면 비주얼이..ㅎㄷㄷ 생선 별로 안좋아하는데 저건 너무 맛있었어 숙대에 이웃집영준이라는 곳인데 분위기도 익선동분위기나구 술 종류도 엄청 많으니까 지효두 꼭 가보길 생선튀김은 필수얌>_<
#
# #지효야나먹어쪄
# --------------------------------------------------
# 학교동기들이랑 익선동! 태국음식점인데 정확한이름은 모르겠다ㅠㅠ 근데 여기는 첫번째사진 푸팟퐁커리맛집이야.. 볶음밥류랑 쌀국수는 좀 (많이)별로였어;
# 익선동 처음이었는데 물가 ㅎㄷㄷ하더라 분위기는 너무 좋은데ㅠㅠ 담엔 익선동 밥 말구 카페로 오는걸루..
#
# #지효야나먹어쪄
# --------------------------------------------------
# 익선동 프랑스 가정식 식당
# 르블란서
#
# 항정살스테이크(강추)
# 라구파스타
# 연어구이,뇨끼
# 라따뚜이
#
# 음식도 빨리 나오고 테이블 회전률도 좋음 뭣보다 분위기가 캡~
#
# #밥먹었어요_아니요
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# #택운이를_위한_뮤슐랭가이드
# #그뮤즈에그뮤즈
# #쟌이뭐먹어
# #라비_맛집_도와드려요
# #갈비찜을밥위에얹어주세횩
#
# 번점 끝나고 익선동 익선디미방
# 부채살 스테이크 맛도리 먹어보러오세욘~
#
# #학연아_널먹을순없잖아
# --------------------------------------------------
# 익선동 살라댕 방콕
#
# 슈림프 팟타이 오믈렛
# 뿌팟퐁커리 맛있오
#
# 빈이 인형 내꺼아님
# #빈아_운동및식단_포기했다
# #호영씨_밥같이_먹읍시다
# #호영아_아아아아
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# 익선동 르블란서
#
# 한억에서 먹는 프렌치 식전빵이 짱 마싯었도 라구파스타가 맛있었다,,
# --------------------------------------------------
# #빈아_운동및식단_포기했다
# #돌잔치_음식추천
# #로하_이거먹으러_왔따나
# #ㅌㅇㅌㅇㅈ
#  백스트리트피자
#  Half & half (Shrimp Gangster + Potato Killer)
#
# 익선동 피자맛집
# 매콤한 새우+달달한 감자
# 단짠조화가 훌륭했고
# 적당한 두께의 담백한 도우라 더 좋았음!
#
# 오늘도 즐거운 산랔프 모임
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# 익선동 끼룩하우스
#
# 교대 넘어가기 전에v.v 회개리카노 타임,, 프랄린 스트러들,, 견과류 카라멜맛… 넘 조와하는 맛임( ་ེིོཻྀཽཾ⌓ ་ེིོཻྀཽཾ) 마들렌 피낭시에도 다 맛있어보였는데 못먹고가서 너무 아쉽(˃̣̣̣̣̣̣︿˂̣̣̣̣̣̣ )
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# 익선동 간판없는식당
#
# 오늘도 맛있엇다 버섯버터스파게티 넘맛 스테이크리조또도 넘맛 맥주 술술 들어가조 진짜 짱맛집… 다음에 오면 꼭 라자냐 먹기로 약속했음( ་ེིོཻྀཽཾ⌓ ་ེིོཻྀཽཾ)
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# 리장수
#
# 차학연이 치즈호두곶감말이 얘기해서 끌어 올리는 전생의 기억.. 익선동 골목중에서도 샛길에 있는 라운지바
# 1차로 샬라댕 조지고갔기때문에 곶감말이에 칵텔만 마심^<^ 내가 마신건 리장수 시그니처칵테일 낙원동신사 저 연기가 계피를 태워 훈연한거
# --------------------------------------------------
# #학연이가_뇸뇸_먹어볼까욘
# 익선동 간판없는식당
#
# 명란스파게티랑 모듬버섯피자 먹고왓서! 음료는 머더라 생맥이었는데,, 쨌던 들다 마쉿지만 개취로 버섯피자 넘맛… 1인 1피자 가넝… 피자의에 수란이 진짜 미친놈이었단자.. 주말이라 대기가 있었는데 학연이는 평일을 노려보자><
# --------------------------------------------------
# #우무이
# 익선동 엘까르니따스
# Imgoingtomurderthistaco
# --------------------------------------------------
# #우즈야_무즈는_이거먹어 #우무이
# 익선동 롤인익선
# 유일하게 먹을수잇는회가 연어인데.. 연어가진짜도톰하구개맛잇습니다  입에 넣는 순간 녹아버림.. 아보카도연어롤이랑 연어초밥은 무적권 시키세요  너무너무 맛잇듬 안이 좁아서 좌석이 별로 없어요 웨이팅이 잇을수잇다는점 참고해주세요
# --------------------------------------------------
# 익선동 냉삼집 미미네
#
# - 냉삼겹 2인분
# - 차돌 된장 술밥
#
# 된장 술밥 맛집
# 담에 된찌 먹으러 또 올게요 ~
# 대신 안 더운 날에
# 가게가 많이 협소하니 주의하시길…
#
# #이재현_치킨이다가아니야
# #주학년_먹는데돈아끼지말자
# #김선우_맛있는걸내가놔둘리가
# #그거먹고_배가찬희
# --------------------------------------------------
# 라미스콘
# 걍 보여서 들어가봤는데 비건/글루텐프리더라고?! 말차팥스콘. 밀크티초코칩스콘. 허니코코넛쿠키 포장해와서 다음날 아침에 먹었는데 맛있었엉 재방문 의사 있어 다른 스콘들이랑 수플레 먹어보고싶엉 청담말구 익선동이랑 샤로수길에두 있는듯!!
# #희철아_고양이는_이런거_못먹겠지
# --------------------------------------------------
# 익선동 호텔세느장
# 루프탑 분위기 개쩔고,,,,
# 칵테일 맛있고,,
#
# #쩸냠냥
# --------------------------------------------------
# 익선동 "반기다" A세트
# 사과 막걸리 /항정살구이/두부 샐러드/차돌박이크림파스타
# 식사메뉴는 비빔밥 올리브파스타 등으로 메뉴 변경 가능
# #학신 #주학년_푸드플렉스
# #주학년_먹는데돈아끼지말자 #JUHAKNYEON #THEBOYZ
# --------------------------------------------------
#  익선동 경성과자점 (홍롱롱 앞집ㅋㅋㅋ)
#
# 찻집인데 차 보단 파운드 케이크가 더 인상에 남네요ㅎㅅㅎ
#
# #학신 #학뭉치 #주학년인형 #주학년 #현재 #현재인형 #핑크현재 #그집즈 #THEBOYZDOLL #쥬스갤러리 #핑재갤러리
# --------------------------------------------------
#  익선동 홍롱롱[轰聋聋]
#
# 딤섬 하나씩 다 먹어봤는데 트러플 교자가 제일 좋았어서 근접샷
# #학신 #학뭉치 #주학년인형 #주학년 #현재 #현재인형 #핑크현재 #THEBOYZDOLL #쥬스갤러리 #핑재갤러리
# --------------------------------------------------

# %% [markdown]
# ### 지역별 데이터 불러오기

# %%
data1 = pd.read_csv('twitter_종로.csv', encoding='utf-8-sig')
data2 = pd.read_csv('twitter_익선.csv', encoding='utf-8-sig')
data3 = pd.read_csv('twitter_혜화.csv', encoding='utf-8-sig')
data4 = pd.read_csv('twitter_부암동.csv', encoding='utf-8-sig')
data5 = pd.read_csv('twitter_평창동.csv', encoding='utf-8-sig')
data6 = pd.read_csv('twitter_삼청동.csv', encoding='utf-8-sig')
data7 = pd.read_csv('twitter_인사동.csv', encoding='utf-8-sig')
data8 = pd.read_csv('twitter_대학로.csv', encoding='utf-8-sig')
data9 = pd.read_csv('twitter_경복궁.csv', encoding='utf-8-sig')
data10 = pd.read_csv('twitter_서촌.csv', encoding='utf-8-sig')
data11 = pd.read_csv('twitter_북촌.csv', encoding='utf-8-sig')
data12 = pd.read_csv('twitter_종각.csv', encoding='utf-8-sig')
data13 = pd.read_csv('twitter_동묘.csv', encoding='utf-8-sig')
data14 = pd.read_csv('twitter_광화문.csv', encoding='utf-8-sig')
data15 = pd.read_csv('twitter_가회.csv', encoding='utf-8-sig')
data16 = pd.read_csv('twitter_안국.csv', encoding='utf-8-sig')
data17 = pd.read_csv('twitter_광장시장.csv', encoding='utf-8-sig')
data18 = pd.read_csv('twitter_낙산공원.csv', encoding='utf-8-sig')
data19 = pd.read_csv('twitter_서순라길.csv', encoding='utf-8-sig')
data20 = pd.read_csv('twitter_정동.csv', encoding='utf-8-sig')
data21 = pd.read_csv('twitter_효자동.csv', encoding='utf-8-sig')
data22 = pd.read_csv('twitter_덕수궁.csv', encoding='utf-8-sig')
data23 = pd.read_csv('twitter_창신동.csv', encoding='utf-8-sig')
data24 = pd.read_csv('twitter_창덕궁.csv', encoding='utf-8-sig')

# %% [markdown]
# ### 익선 & 익선동 통합

# %%
d1 = pd.read_csv('twitter_익선동.csv', encoding='utf-8-sig')
d2 = pd.read_csv('twitter_익선.csv', encoding='utf-8-sig')

# %%
data2 = pd.concat([d1, d2], axis=0)
data2.drop_duplicates()   # 중복 트윗 제거
# Out:
#                                                 tweet
# 0   몽블랑솜 익선동카페\n\n#런쥔이_밥무거쒀\n#박지성_단1g도안줌\n#먹다가_해찬이...
# 1   익선동 달랭이\n\n소곱창전골&뭉티기 히히 마싯더\n\n#태래비전출연맛집\n#조슈아...
# 2   익선동 식물\n\n크로플 조오오오온맛 \n빠순이와 야빠를 동시에 해냅니다..\n\n...
# 3   익선동 우연화\n\n수제 떡갈비 맛집 !\n숯불에서 바로 구워주고 소스도 5가지여서...
# 4   종로찌게마을\n맛있고 양도 많아\n웨이팅도 익선동 구경하면 금방 가서 즐거움\n소주...
# ..                                                ...
# 55  익선 호호식당\n익선 플리퍼스\n\n착한 머글 친구들과 ~ ,, ♡ 여기 두곳\n진...
# 56  #ㄷㅂㅇㅈ\n#상상그이상의_맛집\n#상프들_맛집은_신중해야해\n익선 송암여관\n\n...
# 57  롤인익선\n\n나 연어 먹고싶을때 여기 와。。。\n아보카도 오늘 첨먹어봤는데 아보카...
# 58  #콥이는_콥빼기로주세요\n#아저스트워너러뷰_배배\n나도 가봤다 롤인익선 !!! 무슨...
# 59  종로3가에 있는 익선잡방\n여기 에그 베네딕트랑 라자냐 진짜 맛집!ㅠ\n사람 진짜 ...
#
# [381 rows x 1 columns]

# %% [markdown]
# ### 종로 통합

# %%
pd1 = pd.concat([data1, data2], axis=0)
pd2 = pd.concat([pd1, data3], axis=0)
pd3 = pd.concat([pd2, data4], axis=0)
pd4 = pd.concat([pd3, data5], axis=0)
pd5 = pd.concat([pd4, data6], axis=0)
pd6 = pd.concat([pd5, data7], axis=0)
pd7 = pd.concat([pd6, data8], axis=0)
pd8 = pd.concat([pd7, data9], axis=0)
pd9 = pd.concat([pd8, data10], axis=0)
pd10 = pd.concat([pd9, data11], axis=0)
pd11 = pd.concat([pd10, data12], axis=0)
pd12 = pd.concat([pd11, data13], axis=0)
pd13 = pd.concat([pd12, data14], axis=0)
pd14 = pd.concat([pd13, data15], axis=0)
pd15 = pd.concat([pd14, data16], axis=0)
pd16 = pd.concat([pd15, data17], axis=0)
pd17 = pd.concat([pd16, data18], axis=0)
pd18 = pd.concat([pd17, data19], axis=0)
pd19 = pd.concat([pd18, data20], axis=0)
pd20 = pd.concat([pd19, data21], axis=0)
pd21 = pd.concat([pd20, data22], axis=0)
pd22 = pd.concat([pd21, data23], axis=0)
pd23 = pd.concat([pd22, data24], axis=0)

# %%
pd23
# Out:
#                                                 tweet
# 0    종로5가 백제정육점\n\n육회 비빔밥 한숟가락에 육회 더 올리고 차돌 싸서 먹으면...
# 1   부촌육회 / 종로 5가\n\n육회 1.9\n낙지탕탕이 1.5\n육비(특) 1.3\n...
# 2   종로 okba\n\n여기 그냥 걷다가 너무 추워서 들어간 곳인데 내부 분위기 너무 ...
# 3   종로 광장시장 창신육회 3호점\n\n육회 육사시미 산낙지 세트에 빈대떡 추가\n슬러...
# 4   #재민아_밥먹어 #나나의_맛집탐방기\n#천러야_이거_먹기좋아\n#런쥔이_밥무거쒀\n...
# ..                                                ...
# 8   을지로 분카샤\n이제 창덕궁으로 레쭈고\n#우리배는_식도로만_가\n#맛이여_상상이상...
# 9   행복한 데이뚜\n다음엔 더현대 뿌시기\n익선동 이태리총각\n창덕궁\n익선동 라미스콘...
# 10   안국 플롭 - 종로 맛집\n\n창덕궁 구경하고 간 피자 맛집\n앞에 대기가 6팀이...
# 11  #머거스트디 | 안국 파고\n사실 나만 알고 안올리려고 했는데 여기 커피가 너무 맛...
# 12  안국 고다\n홍매화 보러 창덕궁 다녀왓어요잉\n#밥을먹는거아니었어감동을먹고있었어\n...
#
# [3157 rows x 1 columns]

# %%
pd23.to_csv("twitter_종로_통합.csv", index=False)

# %% [markdown]
# tweets = []
# for hashtag in hashtags1:
#     url = "https://twitter.com/search?q=종로%20{0}&src=typed_query&f=live".format(hashtag)   # 지역명과 해시태그셋 url에 넘겨주기
#     driver.get(url)
#     time.sleep(random.uniform(3, 10))
#
#     before_location = driver.execute_script("return window.pageYOffset")
#
#     while True:
#
#         driver.execute_script("window.scrollTo(0,{})".format(before_location + 2000))
#         time.sleep(random.uniform(3, 7))
#
#         after_location = driver.execute_script("return window.pageYOffset")
#
#         if before_location == after_location:     # 스크롤이 끝까지 내려갔을 경우 중단
#             break
#
#         else:
#             html_content = driver.page_source
#             soup = BeautifulSoup(html_content, 'html.parser')
#             posts = soup.find_all(attrs={"data-testid": "tweetText"})
#
#             for post in posts:
#                 if post.text not in tweets:     # 중복 트윗이 아닌 경우 tweets 리스트에 추가
#                     tweets.append(post.text)
#                     print(post.text)
#                     print("-" * 50)
#                 else:
#                     pass
#
#             before_location = driver.execute_script("return window.pageYOffset")
#
# df = pd.DataFrame(tweets, columns=['tweet'])
# df.to_csv("twitter_{0}.csv".format(location), index=False)     # 지역별 csv 파일 저장

# %% [markdown]
# for location in locations:
#     tweets = []
#
#     for hashtag in hashtags1:
#         url = "https://twitter.com/search?q={0}%20{1}&src=typed_query".format(location, hashtag)   # 지역명과 해시태그셋 url에 넘겨주기
#         driver.get(url)
#         time.sleep(5)
#
#         before_location = driver.execute_script("return window.pageYOffset")
#
#         while True:
#
#             driver.execute_script("window.scrollTo(0,{})".format(before_location + 2000))
#             time.sleep(3)
#
#             after_location = driver.execute_script("return window.pageYOffset")
#
#             if before_location == after_location:     # 스크롤이 끝까지 내려갔을 경우 중단
#                 break
#
#             else:
#                 html_content = driver.page_source
#                 soup = BeautifulSoup(html_content, 'html.parser')
#                 posts = soup.find_all(attrs={"data-testid": "tweetText"})
#
#                 for post in posts:
#                     if post.text not in tweets:     # 중복 트윗이 아닌 경우 tweets 리스트에 추가
#                         tweets.append(post.text)
#                         print(post.text)
#                         print("-" * 50)
#                     else:
#                         pass
#
#                 before_location = driver.execute_script("return window.pageYOffset")
#
#     df = pd.DataFrame(tweets, columns=['tweet'])
#     df.to_csv("twitter_{0}.csv".format(location), index=False)     # 지역별 csv 파일 저장
